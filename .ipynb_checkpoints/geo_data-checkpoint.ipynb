# %%
'''

USGS (US Geological Survey) publishes earthquake data. Here’s a feed spanning all domestic earthquakes from the past month:
https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_month.geojson

Using this JSON feed:
1) identify every earthquake in California from past month,
2) list them by increasing magnitude
3. and finally output in a format resembling the following e.g.:

2017-07-13T22:32:48+00:00 | 15km SE of Mammoth Lakes, California | Magnitude: 0.92
2017-07-13T22:49:58+00:00 | 8km ENE of Mammoth Lakes, California | Magnitude: 0.92
2017-07-13T22:37:52+00:00 | 12km E of Mammoth Lakes, California | Magnitude: 0.95
2017-07-13T20:43:37+00:00 | 3km NW of Greenville, California | Magnitude: 1
2017-07-13T22:31:04+00:00 | 11km E of Mammoth Lakes, California | Magnitude: 1.31
2017-07-13T22:45:28+00:00 | 37km SE of Bridgeport, California | Magnitude: 1.7
2017-07-13T22:54:30+00:00 | 3km SE of Atascadero, California | Magnitude: 2.04
2017-07-13T22:09:53+00:00 | 41km SW of Ferndale, California | Magnitude: 2.76

'''

# %%
import json
import requests
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
filename = './all_month.geojson'
url = 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_month.geojson'

def load_data():
    try:
        resp = requests.get(url)
        resp_json = resp.json()
        
        with open(filename, 'w') as f:
            json.dump(resp_json, filename)
        
        return resp_json
    
    except Exception:
        with open(filename, 'r') as f:
            return json.load(f)

data = load_data()
# Out:
# --------------------------------------------------------------------------
# AttributeError                           Traceback (most recent call last)
# <ipython-input-31-ff674aa0a813> in <module>()
#      10
#      11
# ---> 12 data = load_data()
#
# <ipython-input-31-ff674aa0a813> in load_data()
#       6         resp = requests.get(url)
#       7         resp_json = resp.json()
# ----> 8         json.dump(resp_json, filename)
#       9         return resp_json
#      10
#
# /usr/local/Cellar/python@2/2.7.14_3/Frameworks/Python.framework/Versions/2.7/lib/python2.7/json/__init__.pyc in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, encoding, default, sort_keys, **kw)
#     188     # a debuggability cost
#     189     for chunk in iterable:
# --> 190         fp.write(chunk)
#     191
#     192
#
# AttributeError: 'str' object has no attribute 'write'

# %%
# store as DataFrame
df = pd.io.json.json_normalize(data['features'])
data_size = len(df)
properties = list(df)
sources = df['properties.type'].unique()

import time

start = time.time()

df = df[['properties.time', 'properties.place', 'properties.mag']] # keep columns relevant to output
# df = df[['properties.time', 'properties.place', 'properties.mag', 'properties.type']] # keep columns relevant to output
df_cali = df[df['properties.place'].str.contains('California|CA')] # find entries with 'place' value containing 'California' or 'CA', 628 records
# df_cali = df[(df['properties.place'].str.contains('California|CA')) & (df['properties.type'] == 'earthquake')] # find entries with 'place' value containing 'California' or 'CA'
df_cali_sorted = df_cali.sort_values(['properties.mag', 'properties.time']) # sort by magnitude, then time occurred
# df_cali_sorted['properties.time'] = pd.to_datetime(df_cali_sorted['properties.time'], unit='ms').dt.tz_localize('UTC').dt.strftime('%Y-%m-%dT%H:%M:%S%z') # unit=milliseconds
# df_cali_sorted['properties.time'] = pd.to_datetime(df_cali_sorted['properties.time'], unit='ms').dt.tz_localize('UTC').dt.strftime('%Y-%m-%dT%H:%M:%S') # unit=milliseconds
# df_cali_sorted['properties.time'] = df_cali_sorted['properties.time'].apply(format_time)

results = []
print len(df_cali_sorted)


format_time = lambda x: datetime.utcfromtimestamp(int(x) / 1000.0).strftime('%Y-%m-%dT%H:%M:%S') + '+00:00'
format_place = lambda x: str(x)
format_mag = lambda x: 'Magnitude: {}'.format(x) # better to use str.format as it converts its arguments into strings
format_output = lambda (idx, row): '{} | {} | {}'.format(format_time(row['properties.time']), 
                                                format_place(row['properties.place']), 
                                                format_mag(row['properties.mag']))


results = map(format_output, df_cali_sorted.iterrows())


# time 0.67157292366, iterrows is slower


# output format: 2017-07-13T22:32:48+00:00 | 15km SE of Mammoth Lakes, California | Magnitude: 0.92
# Out:
# 3221
# 2018-03-28T06:09:34+00:00 | 6km WNW of Cobb, CA | Magnitude: -0.41
# 2018-03-29T12:43:39+00:00 | 3km E of Truckee, California | Magnitude: -0.3
# 2018-03-31T00:24:48+00:00 | 4km NNE of Truckee, California | Magnitude: -0.3
# 2018-04-18T05:49:52+00:00 | 2km WSW of Tahoe Vista, California | Magnitude: -0.3
# 2018-04-15T08:27:59+00:00 | 8km WSW of Anza, CA | Magnitude: -0.28
# 2018-04-02T08:16:05+00:00 | 4km NW of Anza, CA | Magnitude: -0.27
# 2018-04-15T15:06:17+00:00 | 3km SW of Anderson Springs, CA | Magnitude: -0.26
# 2018-04-09T22:46:36+00:00 | 1km NE of The Geysers, CA | Magnitude: -0.24
# 2018-04-17T01:28:31+00:00 | 2km ENE of The Geysers, CA | Magnitude: -0.24
# 2018-04-04T01:45:26+00:00 | 11km SSW of Idyllwild, CA | Magnitude: -0.22
# 2018-04-05T03:39:58+00:00 | 7km ENE of Mammoth Lakes, CA | Magnitude: -0.22
# 2018-03-31T05:18:44+00:00 | 9km E of Mammoth Lakes, CA | Magnitude: -0.21
# 2018-04-21T20:53:36+00:00 | 2km ENE of The Geysers, CA | Magnitude: -0.21
# 2018-04-23T13:56:35+00:00 | 11km E of Mammoth Lakes, CA | Magnitude: -0.21
# 2018-04-04T06:15:06+00:00 | 5km WSW of Anza, CA | Magnitude: -0.2
# 2018-04-10T05:26:36+00:00 | 3km N of Dollar Point, California | Magnitude: -0.2
# 2018-04-17T05:51:01+00:00 | 9km NNW of Truckee, California | Magnitude: -0.2
# 2018-04-22T05:09:29+00:00 | 3km WSW of Tahoe Vista, California | Magnitude: -0.2
# 2018-04-22T07:04:46+00:00 | 3km WSW of Tahoe Vista, California | Magnitude: -0.2
# 2018-04-14T04:34:01+00:00 | 2km SSW of Anderson Springs, CA | Magnitude: -0.18
# 2018-04-01T06:55:14+00:00 | 4km W of Mammoth Lakes, CA | Magnitude: -0.16
# 2018-04-14T01:05:16+00:00 | 14km ESE of Mammoth Lakes, CA | Magnitude: -0.15
# 2018-03-31T16:10:27+00:00 | 6km WNW of Mammoth Lakes, CA | Magnitude: -0.14
# 2018-04-02T01:52:16+00:00 | 6km S of Idyllwild, CA | Magnitude: -0.14
# 2018-03-30T03:00:56+00:00 | 11km ESE of Mammoth Lakes, CA | Magnitude: -0.13
# 2018-04-03T19:11:34+00:00 | 9km NE of Aguanga, CA | Magnitude: -0.13
# 2018-04-07T13:40:40+00:00 | 9km E of Mammoth Lakes, CA | Magnitude: -0.13
# 2018-04-10T16:47:55+00:00 | 9km NE of Aguanga, CA | Magnitude: -0.11
# 2018-04-23T06:28:23+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: -0.11
# 2018-03-31T04:15:55+00:00 | 9km N of Truckee, California | Magnitude: -0.1
# 2018-03-31T15:15:18+00:00 | 9km WNW of Sunnyside-Tahoe City, California | Magnitude: -0.1
# 2018-04-01T02:24:22+00:00 | 29km SSE of Portola, California | Magnitude: -0.1
# 2018-04-01T10:22:54+00:00 | 7km N of Truckee, California | Magnitude: -0.1
# 2018-04-01T10:25:49+00:00 | 7km N of Truckee, California | Magnitude: -0.1
# 2018-04-05T15:07:06+00:00 | 7km S of Portola, California | Magnitude: -0.1
# 2018-04-09T09:24:46+00:00 | 15km NW of Truckee, California | Magnitude: -0.1
# 2018-04-13T06:34:36+00:00 | 3km WSW of Tahoe Vista, California | Magnitude: -0.1
# 2018-04-20T20:11:19+00:00 | 10km NE of Aguanga, CA | Magnitude: -0.1
# 2018-04-22T05:01:07+00:00 | 3km WSW of Tahoe Vista, California | Magnitude: -0.1
# 2018-04-24T09:36:26+00:00 | 5km WNW of Tahoe Vista, California | Magnitude: -0.1
# 2018-04-05T11:59:42+00:00 | 10km NE of Aguanga, CA | Magnitude: -0.09
# 2018-04-04T23:43:10+00:00 | 11km ESE of Mammoth Lakes, CA | Magnitude: -0.08
# 2018-04-22T10:55:19+00:00 | 8km E of Mammoth Lakes, CA | Magnitude: -0.08
# 2018-04-03T01:37:08+00:00 | 9km NE of Aguanga, CA | Magnitude: -0.07
# 2018-04-04T08:59:14+00:00 | 10km S of Idyllwild, CA | Magnitude: -0.07
# 2018-04-22T17:05:27+00:00 | 10km ESE of Mammoth Lakes, CA | Magnitude: -0.07
# 2018-04-01T00:42:37+00:00 | 6km W of Mammoth Lakes, CA | Magnitude: -0.05
# 2018-04-07T09:48:31+00:00 | 1km N of Cobb, CA | Magnitude: -0.05
# 2018-04-20T22:43:17+00:00 | 2km NE of Anza, CA | Magnitude: -0.05
# 2018-04-02T03:55:18+00:00 | 10km NE of Aguanga, CA | Magnitude: -0.02
# 2018-04-04T23:40:28+00:00 | 11km ESE of Mammoth Lakes, CA | Magnitude: -0.02
# 2018-03-30T22:43:45+00:00 | 6km SSW of Mammoth Lakes, CA | Magnitude: -0.01
# 2018-04-05T03:54:13+00:00 | 7km ENE of Mammoth Lakes, CA | Magnitude: -0.01
# 2018-04-14T15:46:09+00:00 | 6km SSW of Mammoth Lakes, CA | Magnitude: -0.01
# 2018-03-30T12:04:42+00:00 | 10km NNE of Truckee, California | Magnitude: 0.0
# 2018-04-08T20:42:46+00:00 | 3km SSW of Tahoe Vista, California | Magnitude: 0.0
# 2018-04-18T19:17:00+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.0
# 2018-04-21T18:31:27+00:00 | 12km SW of Mammoth Lakes, CA | Magnitude: 0.0
# 2018-04-23T21:28:35+00:00 | 11km WSW of Anza, CA | Magnitude: 0.0
# 2018-03-29T13:59:23+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.01
# 2018-04-17T11:12:26+00:00 | 11km E of Mammoth Lakes, CA | Magnitude: 0.01
# 2018-04-22T18:10:39+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.01
# 2018-04-02T01:18:56+00:00 | 5km SSW of Mammoth Lakes, CA | Magnitude: 0.02
# 2018-04-22T17:08:30+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.02
# 2018-04-22T17:09:27+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.02
# 2018-04-22T19:27:49+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.02
# 2018-04-02T09:27:43+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.03
# 2018-04-22T17:45:35+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.03
# 2018-04-21T08:41:59+00:00 | 3km NE of Mammoth Lakes, CA | Magnitude: 0.04
# 2018-04-02T03:12:30+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.05
# 2018-04-07T02:44:37+00:00 | 10km W of Mammoth Lakes, CA | Magnitude: 0.05
# 2018-04-11T12:11:59+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.05
# 2018-04-17T11:29:15+00:00 | 5km ESE of Mammoth Lakes, CA | Magnitude: 0.05
# 2018-04-18T11:55:40+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.05
# 2018-04-21T16:39:14+00:00 | 8km E of Mammoth Lakes, CA | Magnitude: 0.05
# 2018-04-01T06:54:58+00:00 | 3km W of Mammoth Lakes, CA | Magnitude: 0.06
# 2018-04-05T10:01:58+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.06
# 2018-04-10T17:15:28+00:00 | 10km NW of The Geysers, CA | Magnitude: 0.06
# 2018-04-22T11:16:53+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.06
# 2018-04-01T06:55:29+00:00 | 4km W of Mammoth Lakes, CA | Magnitude: 0.07
# 2018-04-01T15:22:53+00:00 | 23km E of Little Lake, CA | Magnitude: 0.07
# 2018-04-04T01:48:17+00:00 | 7km NW of The Geysers, CA | Magnitude: 0.07
# 2018-04-05T03:24:06+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.07
# 2018-04-01T14:58:08+00:00 | 6km NW of Anza, CA | Magnitude: 0.08
# 2018-04-04T04:01:11+00:00 | 26km ENE of Coso Junction, CA | Magnitude: 0.08
# 2018-03-31T02:53:38+00:00 | 14km SE of Mammoth Lakes, CA | Magnitude: 0.09
# 2018-04-04T10:27:05+00:00 | 11km NE of Aguanga, CA | Magnitude: 0.09
# 2018-04-04T11:38:02+00:00 | 14km ESE of Anza, CA | Magnitude: 0.09
# 2018-04-05T00:31:38+00:00 | 3km ENE of Mammoth Lakes, CA | Magnitude: 0.09
# 2018-03-29T10:54:23+00:00 | 56km ENE of Lone Pine, California | Magnitude: 0.1
# 2018-03-31T13:28:14+00:00 | 15km NW of Truckee, California | Magnitude: 0.1
# 2018-04-01T06:55:57+00:00 | 6km W of Mammoth Lakes, CA | Magnitude: 0.1
# 2018-04-01T15:47:53+00:00 | 8km N of Truckee, California | Magnitude: 0.1
# 2018-04-01T19:27:38+00:00 | 5km SSW of Mammoth Lakes, CA | Magnitude: 0.1
# 2018-04-02T07:53:27+00:00 | 3km WSW of Tahoe Vista, California | Magnitude: 0.1
# 2018-04-03T05:52:47+00:00 | 15km ESE of Portola, California | Magnitude: 0.1
# 2018-04-03T21:31:17+00:00 | 7km NNW of Truckee, California | Magnitude: 0.1
# 2018-04-23T07:29:41+00:00 | 8km E of Mammoth Lakes, CA | Magnitude: 0.1
# 2018-03-29T12:42:26+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.11
# 2018-03-29T19:49:05+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.11
# 2018-03-30T00:08:45+00:00 | 6km W of Mammoth Lakes, CA | Magnitude: 0.11
# 2018-04-04T14:13:18+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.11
# 2018-04-22T07:50:07+00:00 | 6km E of Ocotillo, CA | Magnitude: 0.11
# 2018-04-02T20:01:36+00:00 | 2km NNW of The Geysers, CA | Magnitude: 0.12
# 2018-04-16T01:27:29+00:00 | 6km ESE of Mammoth Lakes, CA | Magnitude: 0.12
# 2018-04-22T18:55:55+00:00 | 11km E of Mammoth Lakes, CA | Magnitude: 0.12
# 2018-03-29T10:50:47+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.13
# 2018-04-04T12:53:23+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.13
# 2018-04-05T05:36:52+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.13
# 2018-04-06T12:59:29+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.13
# 2018-04-10T08:15:36+00:00 | 6km WNW of Cobb, CA | Magnitude: 0.13
# 2018-04-25T10:40:52+00:00 | 8km NE of Aguanga, CA | Magnitude: 0.13
# 2018-04-02T11:10:46+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.14
# 2018-04-02T17:12:49+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.14
# 2018-04-06T02:59:34+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.14
# 2018-04-20T18:26:58+00:00 | 12km W of Mammoth Lakes, CA | Magnitude: 0.14
# 2018-04-21T08:48:05+00:00 | 10km W of Anza, CA | Magnitude: 0.14
# 2018-04-10T16:01:01+00:00 | 14km SE of Mammoth Lakes, CA | Magnitude: 0.15
# 2018-04-17T17:11:58+00:00 | 14km WSW of Mammoth Lakes, CA | Magnitude: 0.15
# 2018-04-23T03:12:28+00:00 | 7km ESE of Mammoth Lakes, CA | Magnitude: 0.15
# 2018-03-29T19:49:20+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.16
# 2018-04-02T03:28:20+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.16
# 2018-04-06T07:56:48+00:00 | 12km ENE of Mammoth Lakes, CA | Magnitude: 0.16
# 2018-04-07T22:21:53+00:00 | 6km NW of The Geysers, CA | Magnitude: 0.16
# 2018-04-10T12:31:42+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.16
# 2018-04-18T12:34:35+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.16
# 2018-03-30T13:22:31+00:00 | 3km W of Cobb, CA | Magnitude: 0.17
# 2018-03-30T16:49:47+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.17
# 2018-03-31T08:43:53+00:00 | 7km WNW of The Geysers, CA | Magnitude: 0.17
# 2018-04-02T04:34:03+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.17
# 2018-04-03T08:35:18+00:00 | 4km WNW of Cabazon, CA | Magnitude: 0.17
# 2018-04-03T18:00:52+00:00 | 11km WSW of Morongo Valley, CA | Magnitude: 0.17
# 2018-04-05T02:31:06+00:00 | 4km W of Cobb, CA | Magnitude: 0.17
# 2018-04-16T20:51:39+00:00 | 15km ESE of Viola, CA | Magnitude: 0.17
# 2018-04-19T03:56:30+00:00 | 14km W of Toms Place, CA | Magnitude: 0.17
# 2018-04-02T09:40:18+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.18
# 2018-04-05T04:39:57+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.18
# 2018-04-06T17:14:31+00:00 | 5km WSW of Anza, CA | Magnitude: 0.18
# 2018-04-19T22:07:45+00:00 | 9km ENE of Aguanga, CA | Magnitude: 0.18
# 2018-03-29T00:42:19+00:00 | 10km ENE of Mammoth Lakes, CA | Magnitude: 0.19
# 2018-04-02T06:02:33+00:00 | 4km WSW of Cobb, CA | Magnitude: 0.19
# 2018-04-03T05:32:53+00:00 | 4km NNW of The Geysers, CA | Magnitude: 0.19
# 2018-04-05T02:29:52+00:00 | 6km SSW of Mammoth Lakes, CA | Magnitude: 0.19
# 2018-04-06T04:01:04+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.19
# 2018-04-06T07:03:11+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.19
# 2018-04-07T16:05:10+00:00 | 2km WNW of The Geysers, CA | Magnitude: 0.19
# 2018-04-14T10:15:35+00:00 | 5km NW of The Geysers, CA | Magnitude: 0.19
# 2018-04-15T06:00:50+00:00 | 9km ENE of Aguanga, CA | Magnitude: 0.19
# 2018-04-21T02:03:08+00:00 | 13km ESE of Mammoth Lakes, CA | Magnitude: 0.19
# 2018-04-21T20:52:21+00:00 | 8km E of Mammoth Lakes, CA | Magnitude: 0.19
# 2018-04-23T11:47:47+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.19
# 2018-03-28T07:57:48+00:00 | 55km ENE of Big Pine, California | Magnitude: 0.2
# 2018-03-28T08:31:44+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.2
# 2018-03-31T13:24:00+00:00 | 14km NW of Truckee, California | Magnitude: 0.2
# 2018-04-03T17:37:23+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.2
# 2018-04-04T09:48:34+00:00 | 17km NW of Truckee, California | Magnitude: 0.2
# 2018-04-07T06:20:00+00:00 | 3km SSE of Idyllwild, CA | Magnitude: 0.2
# 2018-04-07T08:25:18+00:00 | 8km NE of Aguanga, CA | Magnitude: 0.2
# 2018-04-10T12:29:48+00:00 | 64km NE of Lone Pine, California | Magnitude: 0.2
# 2018-04-18T05:50:19+00:00 | 2km WSW of Tahoe Vista, California | Magnitude: 0.2
# 2018-04-22T14:30:55+00:00 | 45km ENE of Searles Valley, California | Magnitude: 0.2
# 2018-04-24T05:59:39+00:00 | 55km NNE of Fort Irwin, California | Magnitude: 0.2
# 2018-04-24T08:14:57+00:00 | 31km NE of Portola, California | Magnitude: 0.2
# 2018-03-28T22:11:38+00:00 | 4km W of Cobb, CA | Magnitude: 0.21
# 2018-04-04T01:02:13+00:00 | 7km NW of The Geysers, CA | Magnitude: 0.21
# 2018-04-07T11:03:26+00:00 | 1km SW of Lake Henshaw, CA | Magnitude: 0.21
# 2018-04-19T11:38:46+00:00 | 7km NE of Aguanga, CA | Magnitude: 0.21
# 2018-03-28T11:26:11+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.22
# 2018-03-29T09:59:30+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.22
# 2018-04-02T10:53:46+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.22
# 2018-04-02T16:47:11+00:00 | 4km S of Idyllwild, CA | Magnitude: 0.22
# 2018-04-08T01:39:11+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.22
# 2018-04-08T20:07:21+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.22
# 2018-04-11T02:36:01+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.22
# 2018-04-13T16:47:36+00:00 | 5km WNW of Cobb, CA | Magnitude: 0.22
# 2018-04-21T00:44:31+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.22
# 2018-04-22T11:57:36+00:00 | 5km W of Mammoth Lakes, CA | Magnitude: 0.22
# 2018-03-26T16:42:58+00:00 | 7km WNW of The Geysers, CA | Magnitude: 0.23
# 2018-03-27T03:36:27+00:00 | 11km ENE of Mammoth Lakes, CA | Magnitude: 0.23
# 2018-03-29T17:32:13+00:00 | 6km W of Cobb, CA | Magnitude: 0.23
# 2018-03-30T13:27:18+00:00 | 3km W of Cobb, CA | Magnitude: 0.23
# 2018-04-07T11:03:20+00:00 | 5km S of Idyllwild, CA | Magnitude: 0.23
# 2018-04-08T02:08:20+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.23
# 2018-04-11T05:03:15+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.23
# 2018-04-12T00:50:21+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.23
# 2018-04-12T03:47:29+00:00 | 5km WSW of Anza, CA | Magnitude: 0.23
# 2018-04-12T04:56:59+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.23
# 2018-04-22T18:30:19+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.23
# 2018-03-28T09:48:15+00:00 | 1km SSW of Lake Henshaw, CA | Magnitude: 0.24
# 2018-03-29T07:32:09+00:00 | 23km E of Little Lake, CA | Magnitude: 0.24
# 2018-03-29T07:47:40+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.24
# 2018-03-31T16:01:49+00:00 | 3km W of Mammoth Lakes, CA | Magnitude: 0.24
# 2018-04-02T03:16:46+00:00 | 6km SSE of Idyllwild, CA | Magnitude: 0.24
# 2018-04-03T07:59:00+00:00 | 20km ESE of Anza, CA | Magnitude: 0.24
# 2018-04-11T08:54:18+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.24
# 2018-04-16T00:06:42+00:00 | 5km NW of The Geysers, CA | Magnitude: 0.24
# 2018-04-21T20:07:40+00:00 | 8km E of Mammoth Lakes, CA | Magnitude: 0.24
# 2018-04-21T23:10:43+00:00 | 11km S of Mammoth Lakes, CA | Magnitude: 0.24
# 2018-04-22T00:30:36+00:00 | 7km SSW of Lake Arrowhead, CA | Magnitude: 0.24
# 2018-04-24T05:03:23+00:00 | 10km ENE of Aguanga, CA | Magnitude: 0.24
# 2018-03-27T10:17:30+00:00 | 8km WNW of The Geysers, CA | Magnitude: 0.25
# 2018-03-30T03:09:10+00:00 | 5km W of Cobb, CA | Magnitude: 0.25
# 2018-03-31T23:32:59+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.25
# 2018-04-03T23:15:13+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.25
# 2018-04-06T04:50:06+00:00 | 10km SW of Anza, CA | Magnitude: 0.25
# 2018-04-07T08:41:50+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.25
# 2018-04-09T00:58:39+00:00 | 11km NE of Aguanga, CA | Magnitude: 0.25
# 2018-04-10T11:35:13+00:00 | 4km W of Cobb, CA | Magnitude: 0.25
# 2018-04-15T23:01:46+00:00 | 7km WNW of The Geysers, CA | Magnitude: 0.25
# 2018-04-22T18:54:19+00:00 | 10km ESE of Mammoth Lakes, CA | Magnitude: 0.25
# 2018-04-23T15:27:08+00:00 | 8km ESE of Mammoth Lakes, CA | Magnitude: 0.25
# 2018-03-26T16:45:40+00:00 | 8km WNW of The Geysers, CA | Magnitude: 0.26
# 2018-03-28T04:26:02+00:00 | 7km NW of The Geysers, CA | Magnitude: 0.26
# 2018-03-28T15:01:28+00:00 | 7km WNW of The Geysers, CA | Magnitude: 0.26
# 2018-03-29T01:26:08+00:00 | 4km SSE of Pacifica, CA | Magnitude: 0.26
# 2018-03-31T17:39:47+00:00 | 9km SW of Idyllwild, CA | Magnitude: 0.26
# 2018-04-02T16:10:52+00:00 | 7km NE of Aguanga, CA | Magnitude: 0.26
# 2018-04-03T09:00:42+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.26
# 2018-04-03T14:13:20+00:00 | 8km WNW of The Geysers, CA | Magnitude: 0.26
# 2018-04-04T12:11:23+00:00 | 8km ESE of Mammoth Lakes, CA | Magnitude: 0.26
# 2018-04-05T09:05:17+00:00 | 5km NW of The Geysers, CA | Magnitude: 0.26
# 2018-04-05T13:32:47+00:00 | 7km WNW of The Geysers, CA | Magnitude: 0.26
# 2018-04-08T04:05:46+00:00 | 12km ESE of Anza, CA | Magnitude: 0.26
# 2018-04-09T03:02:17+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.26
# 2018-04-14T16:09:21+00:00 | 15km SE of Mammoth Lakes, CA | Magnitude: 0.26
# 2018-04-15T15:06:24+00:00 | 8km WNW of The Geysers, CA | Magnitude: 0.26
# 2018-04-18T01:18:51+00:00 | 8km WNW of The Geysers, CA | Magnitude: 0.26
# 2018-04-19T09:08:45+00:00 | 11km WSW of Anza, CA | Magnitude: 0.26
# 2018-04-20T12:14:46+00:00 | 3km W of Cobb, CA | Magnitude: 0.26
# 2018-04-21T15:10:39+00:00 | 4km SW of Mammoth Lakes, CA | Magnitude: 0.26
# 2018-04-22T18:02:30+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.26
# 2018-04-22T18:32:06+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.26
# 2018-04-23T13:47:18+00:00 | 10km ESE of Mammoth Lakes, CA | Magnitude: 0.26
# 2018-04-23T19:02:30+00:00 | 10km ESE of Mammoth Lakes, CA | Magnitude: 0.26
# 2018-04-25T08:34:14+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.26
# 2018-04-07T22:17:37+00:00 | 7km NW of The Geysers, CA | Magnitude: 0.27
# 2018-04-09T08:58:15+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.27
# 2018-04-11T17:17:42+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.27
# 2018-04-12T03:53:50+00:00 | 6km WNW of The Geysers, CA | Magnitude: 0.27
# 2018-04-13T16:57:09+00:00 | 7km WNW of The Geysers, CA | Magnitude: 0.27
# 2018-04-14T06:28:29+00:00 | 6km WNW of The Geysers, CA | Magnitude: 0.27
# 2018-04-21T11:57:05+00:00 | 9km ENE of Aguanga, CA | Magnitude: 0.27
# 2018-04-22T17:20:15+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.27
# 2018-04-22T18:33:33+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.27
# 2018-04-22T20:02:44+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.27
# 2018-03-31T13:25:14+00:00 | 5km NE of Aguanga, CA | Magnitude: 0.28
# 2018-04-01T17:53:22+00:00 | 7km WNW of Cobb, CA | Magnitude: 0.28
# 2018-04-03T14:35:01+00:00 | 13km NNE of Mineral, CA | Magnitude: 0.28
# 2018-04-04T01:55:57+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.28
# 2018-04-05T03:46:31+00:00 | 8km ENE of Mammoth Lakes, CA | Magnitude: 0.28
# 2018-04-07T06:42:21+00:00 | 11km NE of Aguanga, CA | Magnitude: 0.28
# 2018-04-07T08:22:14+00:00 | 16km SW of La Quinta, CA | Magnitude: 0.28
# 2018-04-07T15:26:47+00:00 | 8km WSW of Anza, CA | Magnitude: 0.28
# 2018-04-07T20:38:46+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.28
# 2018-04-07T23:11:53+00:00 | 12km ESE of Mammoth Lakes, CA | Magnitude: 0.28
# 2018-04-09T18:54:00+00:00 | 2km SE of The Geysers, CA | Magnitude: 0.28
# 2018-04-13T01:03:47+00:00 | 4km SE of The Geysers, CA | Magnitude: 0.28
# 2018-04-13T04:40:22+00:00 | 8km WNW of The Geysers, CA | Magnitude: 0.28
# 2018-04-18T02:39:33+00:00 | 12km ENE of Mammoth Lakes, CA | Magnitude: 0.28
# 2018-04-22T17:30:17+00:00 | 10km ESE of Mammoth Lakes, CA | Magnitude: 0.28
# 2018-04-22T17:35:48+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.28
# 2018-04-22T19:01:51+00:00 | 8km ESE of Mammoth Lakes, CA | Magnitude: 0.28
# 2018-04-23T13:12:30+00:00 | 14km WNW of Toms Place, CA | Magnitude: 0.28
# 2018-04-24T16:37:39+00:00 | 16km ESE of Anza, CA | Magnitude: 0.28
# 2018-03-27T17:37:59+00:00 | 9km E of Mammoth Lakes, CA | Magnitude: 0.29
# 2018-03-28T05:51:36+00:00 | 6km NNW of The Geysers, CA | Magnitude: 0.29
# 2018-04-01T06:55:41+00:00 | 4km W of Mammoth Lakes, CA | Magnitude: 0.29
# 2018-04-01T11:06:24+00:00 | 4km E of Banning, CA | Magnitude: 0.29
# 2018-04-01T13:24:42+00:00 | 0km NNW of Sierra Madre, CA | Magnitude: 0.29
# 2018-04-01T22:36:22+00:00 | 6km SSW of Mammoth Lakes, CA | Magnitude: 0.29
# 2018-04-05T01:25:40+00:00 | 6km SSW of Mammoth Lakes, CA | Magnitude: 0.29
# 2018-04-07T06:20:06+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.29
# 2018-04-09T05:32:31+00:00 | 15km SE of Mammoth Lakes, CA | Magnitude: 0.29
# 2018-04-11T06:47:36+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.29
# 2018-04-12T01:44:31+00:00 | 8km WNW of The Geysers, CA | Magnitude: 0.29
# 2018-04-14T16:23:00+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.29
# 2018-04-20T08:12:30+00:00 | 10km ENE of Aguanga, CA | Magnitude: 0.29
# 2018-04-21T08:09:31+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.29
# 2018-04-23T14:59:30+00:00 | 8km NE of Aguanga, CA | Magnitude: 0.29
# 2018-03-27T05:30:50+00:00 | 6km WNW of Cobb, CA | Magnitude: 0.3
# 2018-03-28T01:56:49+00:00 | 3km ENE of Mammoth Lakes, CA | Magnitude: 0.3
# 2018-03-29T09:49:26+00:00 | 11km NNE of Mineral, CA | Magnitude: 0.3
# 2018-03-30T15:21:41+00:00 | 11km ENE of Mammoth Lakes, CA | Magnitude: 0.3
# 2018-03-31T04:22:28+00:00 | 10km S of Idyllwild, CA | Magnitude: 0.3
# 2018-03-31T23:45:56+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.3
# 2018-04-01T17:41:04+00:00 | 10km WNW of The Geysers, CA | Magnitude: 0.3
# 2018-04-02T00:04:23+00:00 | 37km NNE of Searles Valley, California | Magnitude: 0.3
# 2018-04-02T19:06:07+00:00 | 3km SSE of The Geysers, CA | Magnitude: 0.3
# 2018-04-03T08:58:59+00:00 | 6km SSE of Mammoth Lakes, CA | Magnitude: 0.3
# 2018-04-03T20:47:26+00:00 | 10km NNW of Anza, CA | Magnitude: 0.3
# 2018-04-04T13:45:22+00:00 | 11km ENE of Coso Junction, CA | Magnitude: 0.3
# 2018-04-04T15:53:08+00:00 | 6km NW of The Geysers, CA | Magnitude: 0.3
# 2018-04-04T20:16:42+00:00 | 18km NW of Parkfield, CA | Magnitude: 0.3
# 2018-04-05T03:37:07+00:00 | 7km ENE of Mammoth Lakes, CA | Magnitude: 0.3
# 2018-04-05T07:56:26+00:00 | 1km NW of The Geysers, CA | Magnitude: 0.3
# 2018-04-05T12:08:29+00:00 | 13km WNW of Toms Place, CA | Magnitude: 0.3
# 2018-04-05T14:50:56+00:00 | 1km NNW of The Geysers, CA | Magnitude: 0.3
# 2018-04-08T07:24:44+00:00 | 11km W of Anza, CA | Magnitude: 0.3
# 2018-04-08T08:49:12+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.3
# 2018-04-09T11:06:42+00:00 | 15km NW of Truckee, California | Magnitude: 0.3
# 2018-04-10T04:16:01+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.3
# 2018-04-10T23:45:46+00:00 | 63km NE of Searles Valley, California | Magnitude: 0.3
# 2018-04-16T08:08:22+00:00 | 58km NE of Lone Pine, California | Magnitude: 0.3
# 2018-04-16T13:30:20+00:00 | 13km WNW of Toms Place, CA | Magnitude: 0.3
# 2018-04-21T08:52:44+00:00 | 37km ESE of Big Pine, California | Magnitude: 0.3
# 2018-04-22T21:43:03+00:00 | 9km ESE of Mammoth Lakes, CA | Magnitude: 0.3
# 2018-04-23T13:46:26+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.3
# 2018-04-24T03:37:26+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.3
# 2018-04-01T06:57:57+00:00 | 3km W of Mammoth Lakes, CA | Magnitude: 0.31
# 2018-04-02T22:52:21+00:00 | 11km NE of Aguanga, CA | Magnitude: 0.31
# 2018-04-03T01:28:26+00:00 | 8km NE of Aguanga, CA | Magnitude: 0.31
# 2018-04-04T11:53:47+00:00 | 8km ESE of Mammoth Lakes, CA | Magnitude: 0.31
# 2018-04-04T11:54:39+00:00 | 8km ESE of Mammoth Lakes, CA | Magnitude: 0.31
# 2018-04-04T16:21:09+00:00 | 9km NW of The Geysers, CA | Magnitude: 0.31
# 2018-04-05T02:45:31+00:00 | 1km W of Anderson Springs, CA | Magnitude: 0.31
# 2018-04-07T22:52:50+00:00 | 5km W of Cobb, CA | Magnitude: 0.31
# 2018-04-08T04:31:55+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.31
# 2018-04-08T10:24:50+00:00 | 11km ENE of Mammoth Lakes, CA | Magnitude: 0.31
# 2018-04-09T17:15:13+00:00 | 4km SE of The Geysers, CA | Magnitude: 0.31
# 2018-04-10T22:02:48+00:00 | 12km ESE of Anza, CA | Magnitude: 0.31
# 2018-04-17T08:27:19+00:00 | 6km WNW of Cobb, CA | Magnitude: 0.31
# 2018-04-18T08:30:44+00:00 | 7km ENE of Anza, CA | Magnitude: 0.31
# 2018-04-18T13:21:21+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.31
# 2018-04-24T15:25:14+00:00 | 10km ESE of Mammoth Lakes, CA | Magnitude: 0.31
# 2018-03-27T23:39:11+00:00 | 4km E of Mammoth Lakes, CA | Magnitude: 0.32
# 2018-03-28T06:46:54+00:00 | 8km N of Anza, CA | Magnitude: 0.32
# 2018-03-29T15:40:36+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.32
# 2018-03-30T03:09:12+00:00 | 9km ENE of Aguanga, CA | Magnitude: 0.32
# 2018-03-30T05:35:12+00:00 | 9km WNW of The Geysers, CA | Magnitude: 0.32
# 2018-03-30T11:12:07+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.32
# 2018-03-30T13:54:47+00:00 | 1km WNW of The Geysers, CA | Magnitude: 0.32
# 2018-03-31T12:58:44+00:00 | 9km NW of The Geysers, CA | Magnitude: 0.32
# 2018-03-31T14:06:00+00:00 | 9km NW of The Geysers, CA | Magnitude: 0.32
# 2018-04-02T03:16:55+00:00 | 6km SSE of Idyllwild, CA | Magnitude: 0.32
# 2018-04-03T08:55:38+00:00 | 8km NW of The Geysers, CA | Magnitude: 0.32
# 2018-04-04T20:12:54+00:00 | 11km NE of Aguanga, CA | Magnitude: 0.32
# 2018-04-04T20:41:38+00:00 | 7km NW of The Geysers, CA | Magnitude: 0.32
# 2018-04-05T02:41:17+00:00 | 14km ENE of Mammoth Lakes, CA | Magnitude: 0.32
# 2018-04-05T03:53:19+00:00 | 8km ENE of Mammoth Lakes, CA | Magnitude: 0.32
# 2018-04-05T16:26:05+00:00 | 10km WNW of The Geysers, CA | Magnitude: 0.32
# 2018-04-07T01:02:11+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.32
# 2018-04-08T00:54:08+00:00 | 9km SSW of Idyllwild, CA | Magnitude: 0.32
# 2018-04-08T20:04:16+00:00 | 3km NW of Cobb, CA | Magnitude: 0.32
# 2018-04-10T03:22:03+00:00 | 2km NNW of The Geysers, CA | Magnitude: 0.32
# 2018-04-10T20:59:17+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.32
# 2018-04-11T15:39:37+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.32
# 2018-04-15T05:13:28+00:00 | 6km SSW of Mammoth Lakes, CA | Magnitude: 0.32
# 2018-04-15T23:31:08+00:00 | 5km SSW of Mammoth Lakes, CA | Magnitude: 0.32
# 2018-04-18T10:50:12+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.32
# 2018-04-19T04:14:20+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.32
# 2018-04-20T02:07:51+00:00 | 12km ENE of Cloverdale, CA | Magnitude: 0.32
# 2018-04-21T20:46:40+00:00 | 8km E of Mammoth Lakes, CA | Magnitude: 0.32
# 2018-04-22T15:14:16+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.32
# 2018-03-27T04:02:54+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.33
# 2018-03-29T12:24:37+00:00 | 7km W of Mammoth Lakes, CA | Magnitude: 0.33
# 2018-04-01T04:26:55+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.33
# 2018-04-02T02:16:41+00:00 | 7km NW of The Geysers, CA | Magnitude: 0.33
# 2018-04-05T10:55:05+00:00 | 3km E of Mammoth Lakes, CA | Magnitude: 0.33
# 2018-04-08T13:16:04+00:00 | 11km NE of Aguanga, CA | Magnitude: 0.33
# 2018-04-10T17:32:14+00:00 | 6km NNW of The Geysers, CA | Magnitude: 0.33
# 2018-04-12T15:31:07+00:00 | 8km ESE of Mammoth Lakes, CA | Magnitude: 0.33
# 2018-04-18T08:23:54+00:00 | 7km ENE of Anza, CA | Magnitude: 0.33
# 2018-04-19T05:28:13+00:00 | 11km ENE of Mammoth Lakes, CA | Magnitude: 0.33
# 2018-04-20T12:34:45+00:00 | 3km SSE of Idyllwild, CA | Magnitude: 0.33
# 2018-04-21T06:06:09+00:00 | 9km ENE of Aguanga, CA | Magnitude: 0.33
# 2018-04-22T18:36:14+00:00 | 10km ESE of Mammoth Lakes, CA | Magnitude: 0.33
# 2018-04-22T23:18:48+00:00 | 8km E of Mammoth Lakes, CA | Magnitude: 0.33
# 2018-04-23T04:30:35+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.33
# 2018-04-23T12:04:15+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.33
# 2018-04-23T22:47:04+00:00 | 5km SW of Anza, CA | Magnitude: 0.33
# 2018-04-02T08:17:09+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.34
# 2018-04-03T10:33:30+00:00 | 10km WNW of Cobb, CA | Magnitude: 0.34
# 2018-04-04T09:52:43+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.34
# 2018-04-09T17:42:49+00:00 | 3km NW of Cobb, CA | Magnitude: 0.34
# 2018-04-10T09:25:59+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.34
# 2018-04-12T09:55:32+00:00 | 6km WNW of The Geysers, CA | Magnitude: 0.34
# 2018-04-13T22:08:35+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.34
# 2018-04-14T01:28:30+00:00 | 7km WNW of The Geysers, CA | Magnitude: 0.34
# 2018-04-14T18:26:24+00:00 | 6km N of Mineral, CA | Magnitude: 0.34
# 2018-04-16T23:04:18+00:00 | 4km E of Anza, CA | Magnitude: 0.34
# 2018-04-22T17:34:09+00:00 | 9km E of Mammoth Lakes, CA | Magnitude: 0.34
# 2018-04-22T18:12:33+00:00 | 9km E of Mammoth Lakes, CA | Magnitude: 0.34
# 2018-04-22T20:01:15+00:00 | 10km ESE of Mammoth Lakes, CA | Magnitude: 0.34
# 2018-04-23T14:31:11+00:00 | 10km ESE of Mammoth Lakes, CA | Magnitude: 0.34
# 2018-04-23T15:01:05+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.34
# 2018-03-31T10:55:51+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.35
# 2018-04-06T07:49:42+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.35
# 2018-04-06T22:52:51+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.35
# 2018-04-07T06:08:10+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.35
# 2018-04-07T22:52:46+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.35
# 2018-04-08T23:08:04+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.35
# 2018-04-08T23:36:16+00:00 | 10km SSE of Idyllwild, CA | Magnitude: 0.35
# 2018-04-10T01:34:57+00:00 | 6km W of Cobb, CA | Magnitude: 0.35
# 2018-04-11T06:55:00+00:00 | 4km SE of Ontario, CA | Magnitude: 0.35
# 2018-04-17T01:19:25+00:00 | 11km E of Mammoth Lakes, CA | Magnitude: 0.35
# 2018-04-18T08:12:51+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.35
# 2018-04-18T09:25:01+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.35
# 2018-04-19T13:30:57+00:00 | 2km SSW of Anderson Springs, CA | Magnitude: 0.35
# 2018-04-20T07:24:21+00:00 | 8km WSW of Anza, CA | Magnitude: 0.35
# 2018-04-23T06:54:02+00:00 | 6km WNW of Cobb, CA | Magnitude: 0.35
# 2018-03-26T21:19:32+00:00 | 14km SE of Mammoth Lakes, CA | Magnitude: 0.36
# 2018-03-29T04:49:34+00:00 | 23km ESE of Anza, CA | Magnitude: 0.36
# 2018-03-30T08:53:52+00:00 | 1km SSW of Lake Henshaw, CA | Magnitude: 0.36
# 2018-04-01T05:59:14+00:00 | 11km ESE of Anza, CA | Magnitude: 0.36
# 2018-04-01T22:11:40+00:00 | 10km NW of The Geysers, CA | Magnitude: 0.36
# 2018-04-02T03:24:35+00:00 | 5km S of Littlerock, CA | Magnitude: 0.36
# 2018-04-03T09:05:08+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.36
# 2018-04-05T07:04:42+00:00 | 3km ENE of The Geysers, CA | Magnitude: 0.36
# 2018-04-06T13:04:47+00:00 | 10km ENE of Aguanga, CA | Magnitude: 0.36
# 2018-04-07T02:13:11+00:00 | 6km NW of The Geysers, CA | Magnitude: 0.36
# 2018-04-11T03:30:29+00:00 | 1km NE of The Geysers, CA | Magnitude: 0.36
# 2018-04-14T01:22:25+00:00 | 14km WNW of Toms Place, CA | Magnitude: 0.36
# 2018-04-18T14:50:24+00:00 | 8km NNE of Idyllwild, CA | Magnitude: 0.36
# 2018-04-20T15:40:47+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.36
# 2018-04-22T17:01:22+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.36
# 2018-04-22T19:37:59+00:00 | 9km ESE of Mammoth Lakes, CA | Magnitude: 0.36
# 2018-04-22T20:29:04+00:00 | 10km ESE of Mammoth Lakes, CA | Magnitude: 0.36
# 2018-04-22T21:39:55+00:00 | 9km ENE of Mammoth Lakes, CA | Magnitude: 0.36
# 2018-04-22T22:08:27+00:00 | 9km E of Mammoth Lakes, CA | Magnitude: 0.36
# 2018-04-24T10:49:53+00:00 | 7km E of Mammoth Lakes, CA | Magnitude: 0.36
# 2018-03-28T06:44:14+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.37
# 2018-03-28T07:15:15+00:00 | 4km SSE of Mammoth Lakes, CA | Magnitude: 0.37
# 2018-03-30T04:40:12+00:00 | 6km SSE of Idyllwild, CA | Magnitude: 0.37
# 2018-04-01T23:22:05+00:00 | 7km E of Mammoth Lakes, CA | Magnitude: 0.37
# 2018-04-04T11:54:59+00:00 | 8km ESE of Mammoth Lakes, CA | Magnitude: 0.37
# 2018-04-10T01:39:56+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.37
# 2018-04-13T15:57:37+00:00 | 14km ESE of Mammoth Lakes, CA | Magnitude: 0.37
# 2018-04-16T10:25:51+00:00 | 6km WNW of The Geysers, CA | Magnitude: 0.37
# 2018-04-16T13:21:56+00:00 | 2km NNE of The Geysers, CA | Magnitude: 0.37
# 2018-04-17T05:01:54+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.37
# 2018-04-18T03:57:59+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.37
# 2018-04-18T04:36:57+00:00 | 8km NW of The Geysers, CA | Magnitude: 0.37
# 2018-04-22T16:43:45+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.37
# 2018-04-22T17:07:18+00:00 | 10km ESE of Mammoth Lakes, CA | Magnitude: 0.37
# 2018-04-24T11:10:53+00:00 | 8km ESE of Mammoth Lakes, CA | Magnitude: 0.37
# 2018-04-25T14:29:25+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.37
# 2018-04-01T04:29:50+00:00 | 10km ENE of Nuevo, CA | Magnitude: 0.38
# 2018-04-03T13:42:33+00:00 | 12km ESE of Mammoth Lakes, CA | Magnitude: 0.38
# 2018-04-04T01:27:49+00:00 | 12km ESE of Mammoth Lakes, CA | Magnitude: 0.38
# 2018-04-05T03:01:50+00:00 | 6km NW of The Geysers, CA | Magnitude: 0.38
# 2018-04-05T09:23:40+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.38
# 2018-04-08T12:08:22+00:00 | 4km W of Cobb, CA | Magnitude: 0.38
# 2018-04-08T22:39:12+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.38
# 2018-04-11T23:03:51+00:00 | 8km ENE of Aguanga, CA | Magnitude: 0.38
# 2018-04-18T11:38:31+00:00 | 9km E of Mammoth Lakes, CA | Magnitude: 0.38
# 2018-04-19T03:29:49+00:00 | 9km NNW of Anza, CA | Magnitude: 0.38
# 2018-04-19T08:50:13+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.38
# 2018-04-20T06:41:59+00:00 | 13km NW of Warner Springs, CA | Magnitude: 0.38
# 2018-04-20T11:53:25+00:00 | 7km S of Idyllwild, CA | Magnitude: 0.38
# 2018-04-21T21:10:44+00:00 | 16km WSW of Toms Place, CA | Magnitude: 0.38
# 2018-04-22T20:47:32+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.38
# 2018-04-23T01:39:33+00:00 | 8km E of Mammoth Lakes, CA | Magnitude: 0.38
# 2018-04-23T02:21:33+00:00 | 9km ENE of Aguanga, CA | Magnitude: 0.38
# 2018-03-28T14:12:12+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.39
# 2018-03-28T20:18:09+00:00 | 12km ENE of Mammoth Lakes, CA | Magnitude: 0.39
# 2018-03-29T05:51:41+00:00 | 5km NW of The Geysers, CA | Magnitude: 0.39
# 2018-03-30T21:29:28+00:00 | 8km SSW of Idyllwild, CA | Magnitude: 0.39
# 2018-03-31T23:07:24+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.39
# 2018-04-01T13:16:41+00:00 | 16km SW of La Quinta, CA | Magnitude: 0.39
# 2018-04-03T00:21:49+00:00 | 3km NW of The Geysers, CA | Magnitude: 0.39
# 2018-04-04T00:27:38+00:00 | 13km SE of Anza, CA | Magnitude: 0.39
# 2018-04-06T20:52:14+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.39
# 2018-04-07T02:26:35+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.39
# 2018-04-08T13:53:35+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.39
# 2018-04-10T23:12:24+00:00 | 9km SSW of Idyllwild, CA | Magnitude: 0.39
# 2018-04-14T16:45:20+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.39
# 2018-04-14T19:07:56+00:00 | 6km SW of Mammoth Lakes, CA | Magnitude: 0.39
# 2018-04-18T00:31:07+00:00 | 11km NE of Aguanga, CA | Magnitude: 0.39
# 2018-04-22T17:18:28+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.39
# 2018-04-22T17:19:10+00:00 | 10km ESE of Mammoth Lakes, CA | Magnitude: 0.39
# 2018-04-22T20:04:05+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.39
# 2018-04-22T22:15:51+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.39
# 2018-04-24T06:55:05+00:00 | 7km WNW of The Geysers, CA | Magnitude: 0.39
# 2018-03-27T11:41:00+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.4
# 2018-03-27T14:18:20+00:00 | 20km WSW of Portola, California | Magnitude: 0.4
# 2018-03-29T13:33:51+00:00 | 8km WNW of The Geysers, CA | Magnitude: 0.4
# 2018-03-30T06:36:06+00:00 | 7km SW of Anza, CA | Magnitude: 0.4
# 2018-03-31T06:40:24+00:00 | 29km NNW of Truckee, California | Magnitude: 0.4
# 2018-03-31T07:58:46+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.4
# 2018-04-01T00:51:25+00:00 | 5km WNW of Tahoe Vista, California | Magnitude: 0.4
# 2018-04-01T19:57:09+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.4
# 2018-04-02T16:24:15+00:00 | 60km NE of Lone Pine, California | Magnitude: 0.4
# 2018-04-03T03:06:14+00:00 | 10km ENE of Aguanga, CA | Magnitude: 0.4
# 2018-04-04T15:15:46+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.4
# 2018-04-05T04:08:51+00:00 | 8km ENE of Mammoth Lakes, CA | Magnitude: 0.4
# 2018-04-06T04:25:38+00:00 | 8km ESE of Coso Junction, CA | Magnitude: 0.4
# 2018-04-07T01:40:18+00:00 | 17km E of Downieville, California | Magnitude: 0.4
# 2018-04-08T02:04:53+00:00 | 8km NW of The Geysers, CA | Magnitude: 0.4
# 2018-04-08T18:42:21+00:00 | 3km SSW of Tahoe Vista, California | Magnitude: 0.4
# 2018-04-08T21:39:05+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.4
# 2018-04-10T22:28:53+00:00 | 62km NE of Searles Valley, California | Magnitude: 0.4
# 2018-04-12T06:10:33+00:00 | 15km NW of Truckee, California | Magnitude: 0.4
# 2018-04-13T05:43:23+00:00 | 10km ENE of Downieville, California | Magnitude: 0.4
# 2018-04-14T05:33:09+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.4
# 2018-04-14T11:53:28+00:00 | 10km NW of The Geysers, CA | Magnitude: 0.4
# 2018-04-18T12:17:06+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.4
# 2018-04-19T19:44:19+00:00 | 66km E of Searles Valley, California | Magnitude: 0.4
# 2018-04-21T07:26:11+00:00 | 18km ESE of Anza, CA | Magnitude: 0.4
# 2018-04-22T17:44:27+00:00 | 9km ESE of Mammoth Lakes, CA | Magnitude: 0.4
# 2018-04-22T18:05:40+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.4
# 2018-04-22T20:13:09+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.4
# 2018-04-22T23:24:04+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.4
# 2018-04-23T12:58:18+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.4
# 2018-04-24T02:35:30+00:00 | 17km WSW of Portola, California | Magnitude: 0.4
# 2018-04-24T06:00:59+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.4
# 2018-04-24T16:03:38+00:00 | 8km WSW of Anza, CA | Magnitude: 0.4
# 2018-04-24T16:37:24+00:00 | 10km N of Anza, CA | Magnitude: 0.4
# 2018-03-26T18:38:48+00:00 | 10km NNW of Anza, CA | Magnitude: 0.41
# 2018-04-01T08:50:59+00:00 | 18km ESE of Anza, CA | Magnitude: 0.41
# 2018-04-03T23:11:48+00:00 | 7km S of Idyllwild, CA | Magnitude: 0.41
# 2018-04-04T09:48:12+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.41
# 2018-04-04T23:07:41+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.41
# 2018-04-04T23:38:06+00:00 | 4km WSW of Idyllwild, CA | Magnitude: 0.41
# 2018-04-05T14:22:23+00:00 | 8km NNW of Anza, CA | Magnitude: 0.41
# 2018-04-08T00:14:14+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.41
# 2018-04-13T15:00:41+00:00 | 9km ESE of Mammoth Lakes, CA | Magnitude: 0.41
# 2018-04-14T11:04:20+00:00 | 7km WNW of The Geysers, CA | Magnitude: 0.41
# 2018-04-16T06:33:57+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.41
# 2018-04-18T17:22:09+00:00 | 14km ESE of Anza, CA | Magnitude: 0.41
# 2018-04-21T21:13:38+00:00 | 8km SSW of Idyllwild, CA | Magnitude: 0.41
# 2018-04-22T15:31:48+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.41
# 2018-04-22T19:22:49+00:00 | 10km ESE of Mammoth Lakes, CA | Magnitude: 0.41
# 2018-04-22T20:26:13+00:00 | 9km E of Mammoth Lakes, CA | Magnitude: 0.41
# 2018-04-22T20:42:12+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.41
# 2018-03-26T20:03:37+00:00 | 16km NW of Parkfield, CA | Magnitude: 0.42
# 2018-03-27T02:53:52+00:00 | 17km WSW of Toms Place, CA | Magnitude: 0.42
# 2018-04-01T10:36:18+00:00 | 2km NNW of Lake Henshaw, CA | Magnitude: 0.42
# 2018-04-04T07:12:45+00:00 | 7km WNW of The Geysers, CA | Magnitude: 0.42
# 2018-04-05T00:50:40+00:00 | 2km E of Bishop, CA | Magnitude: 0.42
# 2018-04-05T02:03:22+00:00 | 4km ENE of Mammoth Lakes, CA | Magnitude: 0.42
# 2018-04-07T06:14:13+00:00 | 5km WSW of Anza, CA | Magnitude: 0.42
# 2018-04-07T19:17:29+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.42
# 2018-04-07T21:19:22+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.42
# 2018-04-08T15:07:03+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.42
# 2018-04-09T10:34:56+00:00 | 9km SSW of Idyllwild, CA | Magnitude: 0.42
# 2018-04-12T17:01:12+00:00 | 5km E of Mammoth Lakes, CA | Magnitude: 0.42
# 2018-04-14T02:47:32+00:00 | 6km N of Mineral, CA | Magnitude: 0.42
# 2018-04-15T19:47:44+00:00 | 13km W of Toms Place, CA | Magnitude: 0.42
# 2018-04-18T03:43:13+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.42
# 2018-04-21T02:48:20+00:00 | 11km NE of Aguanga, CA | Magnitude: 0.42
# 2018-04-22T17:18:36+00:00 | 10km ESE of Mammoth Lakes, CA | Magnitude: 0.42
# 2018-04-22T17:32:51+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.42
# 2018-04-22T20:49:53+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.42
# 2018-04-23T14:44:12+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.42
# 2018-03-30T07:45:14+00:00 | 6km WNW of The Geysers, CA | Magnitude: 0.43
# 2018-03-30T10:03:31+00:00 | 16km SE of Anza, CA | Magnitude: 0.43
# 2018-03-31T03:24:58+00:00 | 6km WNW of The Geysers, CA | Magnitude: 0.43
# 2018-04-02T12:00:00+00:00 | 9km SW of Anza, CA | Magnitude: 0.43
# 2018-04-04T03:07:45+00:00 | 21km ESE of Anza, CA | Magnitude: 0.43
# 2018-04-04T09:57:29+00:00 | 24km E of Little Lake, CA | Magnitude: 0.43
# 2018-04-05T04:03:41+00:00 | 8km ENE of Mammoth Lakes, CA | Magnitude: 0.43
# 2018-04-05T11:13:12+00:00 | 2km NNW of The Geysers, CA | Magnitude: 0.43
# 2018-04-08T00:12:40+00:00 | 11km E of Parkfield, CA | Magnitude: 0.43
# 2018-04-08T22:12:19+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.43
# 2018-04-09T15:12:37+00:00 | 7km WNW of The Geysers, CA | Magnitude: 0.43
# 2018-04-10T11:10:15+00:00 | 6km SSW of Mammoth Lakes, CA | Magnitude: 0.43
# 2018-04-10T14:01:37+00:00 | 10km NW of The Geysers, CA | Magnitude: 0.43
# 2018-04-10T20:42:04+00:00 | 1km N of Valley Center, CA | Magnitude: 0.43
# 2018-04-12T17:10:32+00:00 | 3km NE of Banning, CA | Magnitude: 0.43
# 2018-04-15T06:54:28+00:00 | 19km SW of La Quinta, CA | Magnitude: 0.43
# 2018-04-17T01:14:23+00:00 | 9km ENE of Aguanga, CA | Magnitude: 0.43
# 2018-04-23T00:57:42+00:00 | 11km E of Mammoth Lakes, CA | Magnitude: 0.43
# 2018-03-29T07:09:59+00:00 | 12km ESE of Mammoth Lakes, CA | Magnitude: 0.44
# 2018-03-30T15:08:12+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.44
# 2018-03-30T17:37:21+00:00 | 4km E of Moreno Valley, CA | Magnitude: 0.44
# 2018-04-03T15:25:39+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.44
# 2018-04-04T10:10:17+00:00 | 8km WSW of Anza, CA | Magnitude: 0.44
# 2018-04-05T00:55:09+00:00 | 8km WNW of The Geysers, CA | Magnitude: 0.44
# 2018-04-05T12:30:24+00:00 | 8km SSW of Idyllwild, CA | Magnitude: 0.44
# 2018-04-08T02:25:55+00:00 | 12km ESE of Anza, CA | Magnitude: 0.44
# 2018-04-13T13:39:03+00:00 | 13km ESE of Anza, CA | Magnitude: 0.44
# 2018-04-13T23:46:47+00:00 | 13km E of Mammoth Lakes, CA | Magnitude: 0.44
# 2018-04-15T00:32:18+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.44
# 2018-04-15T08:27:26+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.44
# 2018-04-15T16:46:21+00:00 | 4km W of Cobb, CA | Magnitude: 0.44
# 2018-04-17T13:18:13+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.44
# 2018-04-18T19:31:13+00:00 | 7km NW of The Geysers, CA | Magnitude: 0.44
# 2018-04-19T17:09:26+00:00 | 7km WNW of The Geysers, CA | Magnitude: 0.44
# 2018-04-21T22:48:41+00:00 | 7km W of Cobb, CA | Magnitude: 0.44
# 2018-04-22T10:28:17+00:00 | 7km NW of The Geysers, CA | Magnitude: 0.44
# 2018-04-22T13:11:46+00:00 | 8km NW of The Geysers, CA | Magnitude: 0.44
# 2018-04-23T14:09:08+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.44
# 2018-04-24T09:23:47+00:00 | 12km SW of La Quinta, CA | Magnitude: 0.44
# 2018-04-03T20:56:05+00:00 | 6km NW of The Geysers, CA | Magnitude: 0.45
# 2018-04-05T05:09:23+00:00 | 4km SW of Idyllwild, CA | Magnitude: 0.45
# 2018-04-07T10:58:30+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.45
# 2018-04-07T16:23:55+00:00 | 10km WNW of Cobb, CA | Magnitude: 0.45
# 2018-04-08T21:16:45+00:00 | 11km W of Anza, CA | Magnitude: 0.45
# 2018-04-13T15:55:01+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.45
# 2018-04-14T09:21:09+00:00 | 15km W of Toms Place, CA | Magnitude: 0.45
# 2018-04-16T10:43:56+00:00 | 9km ENE of Aguanga, CA | Magnitude: 0.45
# 2018-04-16T13:38:56+00:00 | 4km NW of The Geysers, CA | Magnitude: 0.45
# 2018-04-18T23:40:26+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.45
# 2018-04-20T14:56:57+00:00 | 9km NNW of Anza, CA | Magnitude: 0.45
# 2018-04-25T09:04:08+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.45
# 2018-03-27T07:05:36+00:00 | 23km ESE of Anza, CA | Magnitude: 0.46
# 2018-03-28T15:49:59+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.46
# 2018-03-29T04:16:53+00:00 | 22km SSW of La Quinta, CA | Magnitude: 0.46
# 2018-03-30T18:59:11+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.46
# 2018-03-31T16:03:27+00:00 | 9km ENE of Aguanga, CA | Magnitude: 0.46
# 2018-03-31T21:37:26+00:00 | 9km NW of The Geysers, CA | Magnitude: 0.46
# 2018-04-01T19:02:04+00:00 | 18km WSW of Toms Place, CA | Magnitude: 0.46
# 2018-04-03T12:01:00+00:00 | 7km NW of The Geysers, CA | Magnitude: 0.46
# 2018-04-04T00:59:36+00:00 | 13km SE of Anza, CA | Magnitude: 0.46
# 2018-04-05T13:10:07+00:00 | 28km E of Coso Junction, CA | Magnitude: 0.46
# 2018-04-07T00:57:30+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.46
# 2018-04-09T07:20:12+00:00 | 10km SSW of Idyllwild, CA | Magnitude: 0.46
# 2018-04-10T11:36:13+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.46
# 2018-04-12T08:47:26+00:00 | 14km WNW of Toms Place, CA | Magnitude: 0.46
# 2018-04-12T12:22:07+00:00 | 7km NW of The Geysers, CA | Magnitude: 0.46
# 2018-04-18T00:31:26+00:00 | 5km S of Mentone, CA | Magnitude: 0.46
# 2018-04-18T02:22:59+00:00 | 2km NNW of The Geysers, CA | Magnitude: 0.46
# 2018-04-19T17:20:48+00:00 | 6km NW of The Geysers, CA | Magnitude: 0.46
# 2018-04-21T19:49:16+00:00 | 4km SE of Loma Linda, CA | Magnitude: 0.46
# 2018-04-22T18:02:46+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.46
# 2018-04-23T08:17:45+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.46
# 2018-04-23T11:04:27+00:00 | 5km E of Mammoth Lakes, CA | Magnitude: 0.46
# 2018-03-27T00:20:49+00:00 | 5km SSE of Mammoth Lakes, CA | Magnitude: 0.47
# 2018-03-30T13:05:33+00:00 | 3km W of Cobb, CA | Magnitude: 0.47
# 2018-03-31T04:31:36+00:00 | 7km SSE of Idyllwild, CA | Magnitude: 0.47
# 2018-03-31T16:25:51+00:00 | 16km SSW of Wrightwood, CA | Magnitude: 0.47
# 2018-04-02T05:51:58+00:00 | 15km E of Mammoth Lakes, CA | Magnitude: 0.47
# 2018-04-03T11:21:59+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.47
# 2018-04-05T04:24:42+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.47
# 2018-04-05T13:09:57+00:00 | 3km S of Cobb, CA | Magnitude: 0.47
# 2018-04-06T01:32:11+00:00 | 7km WNW of Cobb, CA | Magnitude: 0.47
# 2018-04-06T23:46:33+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.47
# 2018-04-09T02:29:31+00:00 | 5km W of Cobb, CA | Magnitude: 0.47
# 2018-04-09T11:08:01+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.47
# 2018-04-09T22:59:05+00:00 | 7km NNE of Anza, CA | Magnitude: 0.47
# 2018-04-09T23:31:17+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.47
# 2018-04-10T18:39:33+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.47
# 2018-04-12T09:45:54+00:00 | 1km ESE of The Geysers, CA | Magnitude: 0.47
# 2018-04-17T10:12:55+00:00 | 2km NNW of The Geysers, CA | Magnitude: 0.47
# 2018-04-18T00:56:21+00:00 | 2km SE of The Geysers, CA | Magnitude: 0.47
# 2018-04-18T09:45:48+00:00 | 7km NW of The Geysers, CA | Magnitude: 0.47
# 2018-04-21T07:10:20+00:00 | 4km W of Cabazon, CA | Magnitude: 0.47
# 2018-04-21T12:29:19+00:00 | 11km SW of Mammoth Lakes, CA | Magnitude: 0.47
# 2018-04-22T18:09:15+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.47
# 2018-04-22T19:38:45+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 0.47
# 2018-04-23T15:52:11+00:00 | 3km SE of The Geysers, CA | Magnitude: 0.47
# 2018-03-28T06:50:43+00:00 | 5km W of Cobb, CA | Magnitude: 0.48
# 2018-03-28T10:04:30+00:00 | 15km N of Claremont, CA | Magnitude: 0.48
# 2018-03-30T19:51:14+00:00 | 16km WSW of Toms Place, CA | Magnitude: 0.48
# 2018-03-31T16:01:34+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.48
# 2018-04-01T14:25:22+00:00 | 8km NE of Aguanga, CA | Magnitude: 0.48
# 2018-04-02T04:27:18+00:00 | 10km ENE of Coso Junction, CA | Magnitude: 0.48
# 2018-04-03T02:41:47+00:00 | 6km WNW of Cobb, CA | Magnitude: 0.48
# 2018-04-06T12:16:33+00:00 | 18km ESE of Anza, CA | Magnitude: 0.48
# 2018-04-06T23:38:32+00:00 | 17km ESE of Anza, CA | Magnitude: 0.48
# 2018-04-07T18:03:07+00:00 | 13km ESE of Anza, CA | Magnitude: 0.48
# 2018-04-09T06:09:48+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.48
# 2018-04-09T07:28:00+00:00 | 5km W of Cobb, CA | Magnitude: 0.48
# 2018-04-09T21:58:30+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.48
# 2018-04-11T08:00:29+00:00 | 6km NW of The Geysers, CA | Magnitude: 0.48
# 2018-04-12T16:48:11+00:00 | 4km W of Cobb, CA | Magnitude: 0.48
# 2018-04-17T06:13:51+00:00 | 1km NNW of The Geysers, CA | Magnitude: 0.48
# 2018-04-17T18:19:58+00:00 | 19km ENE of Coso Junction, CA | Magnitude: 0.48
# 2018-04-19T08:27:38+00:00 | 18km ESE of Anza, CA | Magnitude: 0.48
# 2018-04-22T17:15:14+00:00 | 9km E of Mammoth Lakes, CA | Magnitude: 0.48
# 2018-04-25T05:07:21+00:00 | 10km NE of Aguanga, CA | Magnitude: 0.48
# 2018-03-29T01:58:16+00:00 | 3km NNW of The Geysers, CA | Magnitude: 0.49
# 2018-03-29T22:07:05+00:00 | 12km ENE of Mammoth Lakes, CA | Magnitude: 0.49
# 2018-03-30T02:10:10+00:00 | 30km NNW of Searles Valley, CA | Magnitude: 0.49
# 2018-03-30T19:11:57+00:00 | 3km E of The Geysers, CA | Magnitude: 0.49
# 2018-03-31T11:22:36+00:00 | 2km NW of The Geysers, CA | Magnitude: 0.49
# 2018-04-02T00:41:51+00:00 | 20km E of Anza, CA | Magnitude: 0.49
# 2018-04-02T05:04:45+00:00 | 3km W of Cobb, CA | Magnitude: 0.49
# 2018-04-02T14:39:39+00:00 | 6km WNW of Cobb, CA | Magnitude: 0.49
# 2018-04-04T11:35:30+00:00 | 2km NW of The Geysers, CA | Magnitude: 0.49
# 2018-04-05T06:11:09+00:00 | 8km SSW of Cabazon, CA | Magnitude: 0.49
# 2018-04-06T13:48:51+00:00 | 9km NE of Aguanga, CA | Magnitude: 0.49
# ...
# 2018-04-20T10:11:10+00:00 | 12km SW of Huron, CA | Magnitude: 1.89
# 2018-04-21T07:18:31+00:00 | 6km WNW of Cobb, CA | Magnitude: 1.89
# 2018-04-23T21:07:04+00:00 | 8km W of Templeton, CA | Magnitude: 1.89
# 2018-04-25T06:55:53+00:00 | 11km NNW of Hollister, CA | Magnitude: 1.89
# 2018-04-01T09:35:03+00:00 | 4km NNW of Imperial, CA | Magnitude: 1.9
# 2018-04-02T23:28:01+00:00 | 51km WSW of Guadalupe, CA | Magnitude: 1.9
# 2018-04-08T09:21:37+00:00 | 10km NE of Aguanga, CA | Magnitude: 1.9
# 2018-04-15T19:31:01+00:00 | 3km SE of San Ardo, CA | Magnitude: 1.9
# 2018-04-16T00:27:00+00:00 | 22km N of San Simeon, CA | Magnitude: 1.9
# 2018-04-18T23:24:03+00:00 | 12km W of Templeton, CA | Magnitude: 1.9
# 2018-04-21T16:11:58+00:00 | 8km E of Mammoth Lakes, CA | Magnitude: 1.9
# 2018-04-10T23:35:55+00:00 | 3km SE of San Ardo, CA | Magnitude: 1.91
# 2018-04-20T04:42:35+00:00 | 15km NW of Grapevine, CA | Magnitude: 1.91
# 2018-04-21T18:02:16+00:00 | 4km NNW of Pinnacles, CA | Magnitude: 1.91
# 2018-04-23T09:28:32+00:00 | 18km SW of Ludlow, CA | Magnitude: 1.91
# 2018-03-28T13:04:54+00:00 | 9km WNW of The Geysers, CA | Magnitude: 1.92
# 2018-03-31T00:34:52+00:00 | 5km WNW of The Geysers, CA | Magnitude: 1.92
# 2018-04-14T20:57:28+00:00 | 14km SSE of Tres Pinos, CA | Magnitude: 1.92
# 2018-03-26T22:31:21+00:00 | 8km ESE of Willits, CA | Magnitude: 1.93
# 2018-04-08T19:52:49+00:00 | 9km NE of Aguanga, CA | Magnitude: 1.93
# 2018-04-09T04:25:05+00:00 | 25km NNW of San Simeon, CA | Magnitude: 1.93
# 2018-04-19T19:37:40+00:00 | 10km N of Oroville, CA | Magnitude: 1.93
# 2018-04-23T17:25:22+00:00 | 23km NNE of San Ardo, CA | Magnitude: 1.93
# 2018-03-30T23:28:14+00:00 | 4km NW of The Geysers, CA | Magnitude: 1.94
# 2018-04-07T09:38:10+00:00 | 11km NW of Point Sur, CA | Magnitude: 1.94
# 2018-04-09T20:42:53+00:00 | 8km SSE of Brawley, CA | Magnitude: 1.94
# 2018-04-24T13:39:38+00:00 | 2km SE of Danville, CA | Magnitude: 1.94
# 2018-04-03T04:11:51+00:00 | 2km ESE of Twain, CA | Magnitude: 1.95
# 2018-04-14T19:43:57+00:00 | 5km W of Mammoth Lakes, CA | Magnitude: 1.95
# 2018-04-17T19:49:10+00:00 | 7km NW of The Geysers, CA | Magnitude: 1.95
# 2018-04-24T01:25:09+00:00 | 6km WNW of The Geysers, CA | Magnitude: 1.95
# 2018-03-31T12:22:47+00:00 | 10km NW of Parkfield, CA | Magnitude: 1.96
# 2018-04-22T15:06:29+00:00 | 4km W of Dana Point, CA | Magnitude: 1.96
# 2018-03-31T09:15:26+00:00 | 9km NE of Gilroy, CA | Magnitude: 1.97
# 2018-04-08T21:38:01+00:00 | 7km NW of The Geysers, CA | Magnitude: 1.97
# 2018-04-22T17:27:26+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 1.97
# 2018-03-29T02:28:23+00:00 | 8km WSW of Gilroy, CA | Magnitude: 1.98
# 2018-04-06T16:58:45+00:00 | 5km SSE of Cabazon, CA | Magnitude: 1.98
# 2018-04-24T03:44:07+00:00 | 4km NNE of Brea, CA | Magnitude: 1.98
# 2018-03-26T17:28:50+00:00 | 12km ESE of Pinnacles, CA | Magnitude: 1.99
# 2018-04-01T19:45:47+00:00 | 1km E of The Geysers, CA | Magnitude: 1.99
# 2018-04-06T19:48:01+00:00 | 2km NW of Cobb, CA | Magnitude: 1.99
# 2018-04-07T07:38:58+00:00 | 5km W of Cobb, CA | Magnitude: 1.99
# 2018-04-14T15:21:29+00:00 | 8km NE of Ridgemark, CA | Magnitude: 1.99
# 2018-04-25T02:43:26+00:00 | 8km ESE of Mammoth Lakes, CA | Magnitude: 1.99
# 2018-03-29T07:37:12+00:00 | 28km ENE of Bridgeport, California | Magnitude: 2.0
# 2018-04-02T04:13:17+00:00 | 26km S of Mammoth Lakes, CA | Magnitude: 2.0
# 2018-04-18T18:07:13+00:00 | 9km W of Templeton, CA | Magnitude: 2.0
# 2018-04-22T02:09:19+00:00 | 11km SE of Pinnacles, CA | Magnitude: 2.0
# 2018-04-02T02:47:36+00:00 | 10km ENE of Coso Junction, CA | Magnitude: 2.01
# 2018-04-04T09:34:10+00:00 | 9km NE of Aguanga, CA | Magnitude: 2.01
# 2018-04-09T16:51:04+00:00 | 19km NNE of New Idria, CA | Magnitude: 2.01
# 2018-04-01T08:38:17+00:00 | 10km SE of Pinnacles, CA | Magnitude: 2.02
# 2018-04-06T19:47:40+00:00 | 2km NW of Cobb, CA | Magnitude: 2.02
# 2018-04-07T08:10:26+00:00 | 12km SE of Ocotillo Wells, CA | Magnitude: 2.02
# 2018-03-28T06:04:47+00:00 | 6km WNW of Cobb, CA | Magnitude: 2.03
# 2018-04-05T07:01:57+00:00 | 24km NNW of Tehachapi, CA | Magnitude: 2.03
# 2018-04-08T17:32:01+00:00 | 14km SW of Port Hueneme, CA | Magnitude: 2.03
# 2018-04-12T01:47:54+00:00 | 6km WNW of The Geysers, CA | Magnitude: 2.03
# 2018-04-08T19:21:40+00:00 | 10km NE of Santa Ynez, CA | Magnitude: 2.04
# 2018-04-15T02:59:56+00:00 | 3km NNE of Pinnacles, CA | Magnitude: 2.04
# 2018-04-22T18:18:24+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 2.05
# 2018-04-20T10:47:44+00:00 | 40km NE of Big Bear City, CA | Magnitude: 2.06
# 2018-04-02T21:38:39+00:00 | 23km ESE of Ocotillo Wells, CA | Magnitude: 2.07
# 2018-04-22T23:51:52+00:00 | 18km SW of Ludlow, CA | Magnitude: 2.07
# 2018-04-24T22:13:13+00:00 | 7km NW of The Geysers, CA | Magnitude: 2.07
# 2018-04-01T19:10:04+00:00 | 11km SE of Pinnacles, CA | Magnitude: 2.1
# 2018-04-01T23:04:15+00:00 | 26km ENE of Coso Junction, CA | Magnitude: 2.1
# 2018-04-02T04:03:28+00:00 | 5km ESE of Pinnacles, CA | Magnitude: 2.1
# 2018-04-04T05:14:00+00:00 | 8km WSW of Petrolia, CA | Magnitude: 2.1
# 2018-04-06T18:51:18+00:00 | 11km SE of Pinnacles, CA | Magnitude: 2.1
# 2018-04-07T21:41:59+00:00 | 20km ESE of Ocotillo, CA | Magnitude: 2.1
# 2018-04-23T08:01:11+00:00 | 5km ESE of Temecula, CA | Magnitude: 2.1
# 2018-04-03T18:57:44+00:00 | 16km WNW of Searles Valley, CA | Magnitude: 2.11
# 2018-04-04T17:54:16+00:00 | 4km ESE of San Ramon, CA | Magnitude: 2.11
# 2018-04-12T01:09:15+00:00 | 8km NE of Aguanga, CA | Magnitude: 2.11
# 2018-04-15T07:24:24+00:00 | 4km NNW of Pinnacles, CA | Magnitude: 2.11
# 2018-04-11T06:41:22+00:00 | 6km NNE of Banning, CA | Magnitude: 2.12
# 2018-04-20T16:10:44+00:00 | 6km WNW of Cobb, CA | Magnitude: 2.12
# 2018-04-05T15:06:32+00:00 | 7km NNW of Pinnacles, CA | Magnitude: 2.13
# 2018-04-09T11:02:25+00:00 | 4km ESE of Lytle Creek, CA | Magnitude: 2.13
# 2018-04-12T12:42:30+00:00 | 9km S of Yucca Valley, CA | Magnitude: 2.13
# 2018-04-23T09:24:41+00:00 | 4km ESE of Aromas, CA | Magnitude: 2.13
# 2018-04-12T08:25:34+00:00 | 2km ESE of The Geysers, CA | Magnitude: 2.14
# 2018-04-20T20:26:26+00:00 | 17km ESE of Julian, CA | Magnitude: 2.14
# 2018-04-23T04:14:14+00:00 | 8km E of Gilroy, CA | Magnitude: 2.14
# 2018-04-01T22:45:11+00:00 | 7km SW of Niland, CA | Magnitude: 2.15
# 2018-04-02T00:29:49+00:00 | 42km ESE of Avalon, CA | Magnitude: 2.15
# 2018-04-08T10:17:23+00:00 | 11km NE of Napa, CA | Magnitude: 2.15
# 2018-04-19T10:25:06+00:00 | 22km W of Alpaugh, CA | Magnitude: 2.15
# 2018-03-27T21:39:46+00:00 | 5km NNW of Mountain View Acres, CA | Magnitude: 2.17
# 2018-04-01T19:37:30+00:00 | 10km ENE of Coso Junction, CA | Magnitude: 2.17
# 2018-04-04T10:27:05+00:00 | 10km ENE of Coso Junction, CA | Magnitude: 2.17
# 2018-04-23T02:36:17+00:00 | 4km SSE of Redwood Valley, CA | Magnitude: 2.18
# 2018-03-30T01:56:34+00:00 | 31km NNW of Searles Valley, CA | Magnitude: 2.19
# 2018-04-23T02:29:40+00:00 | 13km NNE of Thousand Palms, CA | Magnitude: 2.19
# 2018-04-25T04:32:26+00:00 | 25km ENE of Tres Pinos, CA | Magnitude: 2.19
# 2018-04-14T10:50:21+00:00 | 3km WSW of Anderson Springs, CA | Magnitude: 2.2
# 2018-04-11T04:03:26+00:00 | 22km WNW of Petrolia, CA | Magnitude: 2.22
# 2018-04-17T15:58:28+00:00 | 9km N of Cabazon, CA | Magnitude: 2.22
# 2018-04-24T06:31:44+00:00 | 6km WNW of The Geysers, CA | Magnitude: 2.22
# 2018-04-25T05:15:33+00:00 | 2km NE of Greenhorn, CA | Magnitude: 2.22
# 2018-03-26T21:25:00+00:00 | 6km W of Templeton, CA | Magnitude: 2.23
# 2018-03-31T12:42:35+00:00 | 1km ESE of The Geysers, CA | Magnitude: 2.23
# 2018-04-20T12:25:24+00:00 | 14km NNW of Coalinga, CA | Magnitude: 2.23
# 2018-04-06T23:06:56+00:00 | 15km SSE of Tres Pinos, CA | Magnitude: 2.24
# 2018-04-11T01:57:34+00:00 | 7km WNW of The Geysers, CA | Magnitude: 2.24
# 2018-04-09T00:58:40+00:00 | 10km SE of Pinnacles, CA | Magnitude: 2.25
# 2018-04-18T17:24:36+00:00 | 14km SE of Boonville, CA | Magnitude: 2.25
# 2018-04-01T22:44:17+00:00 | 7km SW of Niland, CA | Magnitude: 2.26
# 2018-04-10T00:23:04+00:00 | 8km NE of Aguanga, CA | Magnitude: 2.26
# 2018-04-22T03:37:08+00:00 | 14km SW of Westley, CA | Magnitude: 2.26
# 2018-03-31T15:12:11+00:00 | 5km WNW of San Juan Bautista, CA | Magnitude: 2.27
# 2018-04-02T08:18:25+00:00 | 11km E of Los Olivos, CA | Magnitude: 2.27
# 2018-04-04T18:49:27+00:00 | 5km NNW of Pearblossum, CA | Magnitude: 2.27
# 2018-04-21T14:05:39+00:00 | 7km NNW of Highland, CA | Magnitude: 2.27
# 2018-04-01T09:35:55+00:00 | 39km ENE of Lucerne Valley, CA | Magnitude: 2.28
# 2018-04-08T08:55:51+00:00 | 7km SSE of Lopez Point, CA | Magnitude: 2.28
# 2018-04-18T15:06:26+00:00 | 30km NNE of Tulelake, California | Magnitude: 2.28
# 2018-04-15T09:23:30+00:00 | 15km SW of Toms Place, CA | Magnitude: 2.29
# 2018-04-19T05:34:32+00:00 | 8km NE of Aguanga, CA | Magnitude: 2.29
# 2018-04-20T15:25:17+00:00 | 9km NE of Aguanga, CA | Magnitude: 2.29
# 2018-04-23T06:47:07+00:00 | 4km NNW of The Geysers, CA | Magnitude: 2.29
# 2018-04-24T16:52:09+00:00 | 19km ENE of Pinnacles, CA | Magnitude: 2.29
# 2018-03-28T14:10:18+00:00 | 29km ENE of Bridgeport, California | Magnitude: 2.3
# 2018-04-05T23:52:31+00:00 | 10km NE of Santa Ynez, CA | Magnitude: 2.3
# 2018-04-13T21:07:34+00:00 | 3km WSW of Muir Beach, CA | Magnitude: 2.3
# 2018-04-24T00:26:27+00:00 | 21km NNW of Santa Cruz Is. (E end), CA | Magnitude: 2.3
# 2018-04-25T13:54:56+00:00 | 2km SSW of Alamo, CA | Magnitude: 2.3
# 2018-04-02T04:04:13+00:00 | 5km ESE of Pinnacles, CA | Magnitude: 2.31
# 2018-04-03T03:46:11+00:00 | 19km SE of Pinnacles, CA | Magnitude: 2.31
# 2018-04-04T05:41:24+00:00 | 11km NE of Santa Ynez, CA | Magnitude: 2.33
# 2018-04-06T11:06:47+00:00 | 14km SSW of San Simeon, CA | Magnitude: 2.33
# 2018-04-16T07:14:20+00:00 | 8km NE of Aguanga, CA | Magnitude: 2.33
# 2018-04-23T23:18:16+00:00 | 34km NE of Independence, CA | Magnitude: 2.33
# 2018-04-24T14:10:51+00:00 | 14km SSW of Westley, CA | Magnitude: 2.33
# 2018-03-30T01:12:38+00:00 | 11km WSW of Rio Dell, CA | Magnitude: 2.35
# 2018-04-07T07:37:54+00:00 | 5km W of Cobb, CA | Magnitude: 2.35
# 2018-04-06T23:06:15+00:00 | 29km SE of Santa Cruz Is. (NW end), CA | Magnitude: 2.36
# 2018-04-10T06:43:38+00:00 | 9km NE of Aguanga, CA | Magnitude: 2.36
# 2018-04-25T08:14:33+00:00 | 20km SW of New Idria, CA | Magnitude: 2.36
# 2018-04-09T02:47:44+00:00 | 4km NW of Cabazon, CA | Magnitude: 2.37
# 2018-04-02T03:40:43+00:00 | 8km NE of Aguanga, CA | Magnitude: 2.38
# 2018-04-25T14:39:02+00:00 | 11km SW of Durham, CA | Magnitude: 2.38
# 2018-03-26T20:58:57+00:00 | 7km NE of Rohnert Park, CA | Magnitude: 2.39
# 2018-04-08T09:21:23+00:00 | 8km NE of Aguanga, CA | Magnitude: 2.39
# 2018-04-10T08:52:59+00:00 | 23km SE of Pinnacles, CA | Magnitude: 2.39
# 2018-04-25T13:32:27+00:00 | 11km SE of Pinnacles, CA | Magnitude: 2.39
# 2018-04-02T19:36:47+00:00 | 1km SW of Palo Cedro, CA | Magnitude: 2.41
# 2018-04-02T21:00:48+00:00 | 35km W of Petrolia, CA | Magnitude: 2.41
# 2018-04-03T07:20:16+00:00 | 14km SSW of Lompoc, CA | Magnitude: 2.42
# 2018-04-22T21:38:04+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 2.43
# 2018-04-23T03:40:06+00:00 | 8km E of Gilroy, CA | Magnitude: 2.43
# 2018-03-30T03:24:58+00:00 | 20km WNW of Petrolia, CA | Magnitude: 2.44
# 2018-04-11T05:29:17+00:00 | 2km S of Bishop, CA | Magnitude: 2.44
# 2018-04-12T06:24:40+00:00 | 10km E of Hidden Valley Lake, CA | Magnitude: 2.44
# 2018-04-24T22:52:13+00:00 | 7km NW of The Geysers, CA | Magnitude: 2.45
# 2018-03-30T02:17:32+00:00 | 17km NNE of Chilcoot-Vinton, CA | Magnitude: 2.46
# 2018-03-30T06:39:56+00:00 | 7km WSW of Gilroy, CA | Magnitude: 2.46
# 2018-04-20T12:05:17+00:00 | 10km NNW of Hollister, CA | Magnitude: 2.46
# 2018-04-21T18:54:19+00:00 | 4km W of Cobb, CA | Magnitude: 2.46
# 2018-04-18T18:09:46+00:00 | 13km ESE of Borrego Springs, CA | Magnitude: 2.47
# 2018-04-01T21:53:14+00:00 | 22km ESE of Ocotillo Wells, CA | Magnitude: 2.48
# 2018-04-21T03:44:39+00:00 | 2km ENE of Danville, CA | Magnitude: 2.48
# 2018-04-12T10:53:12+00:00 | 3km N of Carson, CA | Magnitude: 2.5
# 2018-04-18T01:09:44+00:00 | 45km W of Petrolia, CA | Magnitude: 2.51
# 2018-04-25T09:47:45+00:00 | 19km NW of Desert Center, CA | Magnitude: 2.51
# 2018-04-03T06:33:08+00:00 | 6km ENE of Redding, CA | Magnitude: 2.52
# 2018-04-06T00:48:56+00:00 | 10km NE of Santa Ynez, CA | Magnitude: 2.53
# 2018-04-19T23:17:37+00:00 | 7km E of Clearlake Oaks, CA | Magnitude: 2.54
# 2018-03-27T22:54:41+00:00 | 17km ESE of Hydesville, CA | Magnitude: 2.55
# 2018-04-06T17:51:23+00:00 | 9km NW of Avenal, CA | Magnitude: 2.57
# 2018-04-22T19:58:15+00:00 | 10km E of Mammoth Lakes, CA | Magnitude: 2.57
# 2018-04-05T19:34:50+00:00 | 30km SW of Santa Cruz Is. (E end), CA | Magnitude: 2.58
# 2018-04-10T06:51:56+00:00 | 32km SSW of Willow Creek, CA | Magnitude: 2.58
# 2018-04-01T10:46:57+00:00 | 5km WNW of San Juan Bautista, CA | Magnitude: 2.6
# 2018-04-08T11:22:53+00:00 | 28km SW of Santa Cruz Is. (E end), CA | Magnitude: 2.6
# 2018-03-27T16:27:07+00:00 | 12km WNW of Rio Vista, CA | Magnitude: 2.61
# 2018-04-05T20:39:41+00:00 | 20km NNW of Simmler, CA | Magnitude: 2.61
# 2018-03-31T09:05:53+00:00 | 9km NE of Gilroy, CA | Magnitude: 2.64
# 2018-04-03T10:58:16+00:00 | 18km SW of Lompoc, CA | Magnitude: 2.66
# 2018-03-28T16:17:25+00:00 | 104km WNW of Ferndale, CA | Magnitude: 2.67
# 2018-04-21T01:13:54+00:00 | 19km ESE of Ocotillo Wells, CA | Magnitude: 2.67
# 2018-04-16T23:31:57+00:00 | 9km ENE of Aguanga, CA | Magnitude: 2.68
# 2018-04-24T22:30:25+00:00 | 11km NNW of Hollister, CA | Magnitude: 2.68
# 2018-04-02T21:26:43+00:00 | 6km NW of The Geysers, CA | Magnitude: 2.7
# 2018-04-10T07:04:12+00:00 | 29km SW of Santa Cruz Is. (E end), CA | Magnitude: 2.7
# 2018-04-21T22:36:55+00:00 | 7km NW of The Geysers, CA | Magnitude: 2.71
# 2018-04-09T16:56:20+00:00 | 2km SW of Bishop, CA | Magnitude: 2.73
# 2018-04-22T12:22:55+00:00 | 18km NNE of Avalon, CA | Magnitude: 2.73
# 2018-03-26T22:22:06+00:00 | 0km WNW of Diablo, CA | Magnitude: 2.74
# 2018-03-30T15:05:39+00:00 | 2km E of Pacheco, CA | Magnitude: 2.79
# 2018-03-31T15:07:31+00:00 | 5km WNW of San Juan Bautista, CA | Magnitude: 2.8
# 2018-04-06T17:59:52+00:00 | 9km SSW of McCloud, CA | Magnitude: 2.8
# 2018-04-05T03:23:31+00:00 | 16km SSE of Tres Pinos, CA | Magnitude: 2.82
# 2018-04-05T05:20:08+00:00 | 16km E of Markleeville, CA | Magnitude: 2.82
# 2018-04-03T15:29:38+00:00 | 18km SSE of Fort Irwin, CA | Magnitude: 2.84
# 2018-04-08T16:48:27+00:00 | 16km WNW of Lake Pillsbury, CA | Magnitude: 2.84
# 2018-03-31T09:59:13+00:00 | 165km W of Trinidad, CA | Magnitude: 2.87
# 2018-04-25T06:19:24+00:00 | 26km WNW of Ludlow, CA | Magnitude: 2.87
# 2018-04-22T23:03:54+00:00 | 8km NE of Aguanga, CA | Magnitude: 2.9
# 2018-04-05T04:11:50+00:00 | 17km SSE of Tres Pinos, CA | Magnitude: 2.91
# 2018-04-19T23:18:28+00:00 | 8km E of Clearlake Oaks, CA | Magnitude: 2.91
# 2018-04-20T12:33:02+00:00 | 5km S of Idyllwild, CA | Magnitude: 2.91
# 2018-04-21T03:43:54+00:00 | 2km ENE of Danville, CA | Magnitude: 2.91
# 2018-04-19T23:51:46+00:00 | 8km SSW of Huron, CA | Magnitude: 2.92
# 2018-04-05T20:22:41+00:00 | 20km NNW of Simmler, CA | Magnitude: 2.93
# 2018-04-20T05:12:34+00:00 | 12km SW of Huron, CA | Magnitude: 2.95
# 2018-04-10T13:23:06+00:00 | 6km NE of Fontana, CA | Magnitude: 3.01
# 2018-03-31T14:33:39+00:00 | 5km WNW of San Juan Bautista, CA | Magnitude: 3.02
# 2018-04-22T05:23:27+00:00 | 23km NNE of San Ardo, CA | Magnitude: 3.11
# 2018-04-09T07:31:59+00:00 | 4km ESE of Lytle Creek, CA | Magnitude: 3.23
# 2018-04-07T13:50:15+00:00 | 60km W of Petrolia, CA | Magnitude: 3.28
# 2018-04-13T02:47:50+00:00 | 26km NW of Ludlow, CA | Magnitude: 3.29
# 2018-04-09T03:52:40+00:00 | 4km NNW of Pinnacles, CA | Magnitude: 3.3
# 2018-04-02T02:53:54+00:00 | 8km NE of Aguanga, CA | Magnitude: 3.37
# 2018-04-07T07:37:15+00:00 | 4km W of Cobb, CA | Magnitude: 3.49
# 2018-04-22T16:04:16+00:00 | 8km NNE of Round Valley, CA | Magnitude: 3.6
# 2018-04-13T15:24:46+00:00 | 22km SSW of Bodfish, CA | Magnitude: 3.69
# 2018-04-16T16:36:48+00:00 | 15km NW of Grapevine, CA | Magnitude: 3.78
# 2018-04-16T16:39:26+00:00 | 9km NNE of Alum Rock, CA | Magnitude: 3.82
# 2018-04-23T00:46:08+00:00 | 13km NNE of Thousand Palms, CA | Magnitude: 3.87
# 2018-04-05T19:29:16+00:00 | 29km SW of Santa Cruz Is. (E end), CA | Magnitude: 5.31
# time 0.67157292366

# %%
import matplotlib.pyplot as plt

# store as GeoPandas DataFrame
gdf = gpd.GeoDataFrame(data)
data_size = len(gdf)
properties = list(gdf)
# print data_size
print list(gdf)
# df['type'].unique()
gdf = gdf[['time', 'place', 'mag', 'geometry']] # keep columns relevant to output
gdf_cali = gdf[gdf['place'].str.contains('California|CA')] # find entries with 'place' value containing 'California' or 'CA', 628 records
gdf_cali_sorted = gdf_cali.sort_values(['mag', 'time']) # sort by magnitude, then time occurred
# format_time = lambda x: datetime.utcfromtimestamp(x / 1000.0).strftime('%Y-%m-%dT%H:%M:%S') + '+00:00'
# gdf_cali_sorted['time'] = gdf_cali_sorted['time'].apply(format_time)

# results = []

print len(gdf_cali_sorted)

(fig, ax) = plt.subplots(figsize=(40,40))
# set aspect to equal. This is done automatically
# when using *geopandas* plot on it's own, but not when
# working with pyplot directly.
ax.set_aspect('equal')

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
usa = world[world['name'] == 'United States']
usa.plot(ax=ax, color='chartreuse', edgecolor='black')
gdf_cali_sorted.plot(ax=ax, column='mag', cmap='OrRd', markersize=5)

plt.show()
gdf_cali_sorted

format_time = lambda x: datetime.utcfromtimestamp(int(x) / 1000.0).strftime('%Y-%m-%dT%H:%M:%S') + '+00:00'
format_place = lambda x: str(x)
format_mag = lambda x: 'Magnitude: {}'.format(x) # better to use str.format as it converts its arguments into strings

for (index, row) in gdf_cali_sorted.iterrows():
#     record = str(row['time']) + ' | ' + str(row['place']) + ' | ' + 'Magnitude: ' + str(row['mag'])
    record = '{} | {} | {}'.format(format_time(row['time']), 
                                   format_place(row['place']), 
                                   format_mag(row['mag']))
    print record

# output format: 2017-07-13T22:32:48+00:00 | 15km SE of Mammoth Lakes, California | Magnitude: 0.92
# Out:
# --------------------------------------------------------------------------
# TypeError                                Traceback (most recent call last)
# <ipython-input-23-150593491b40> in <module>()
#       2
#       3 # store as GeoPandas DataFrame
# ----> 4 gdf = gpd.GeoDataFrame(data)
#       5 data_size = len(gdf)
#       6 properties = list(gdf)
#
# /Users/eric/Library/Python/2.7/lib/python/site-packages/geopandas/geodataframe.pyc in __init__(self, *args, **kwargs)
#      44         crs = kwargs.pop('crs', None)
#      45         geometry = kwargs.pop('geometry', None)
# ---> 46         super(GeoDataFrame, self).__init__(*args, **kwargs)
#      47         self.crs = crs
#      48         if geometry is not None:
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     387                 mgr = self._init_dict({}, index, columns, dtype=dtype)
#     388         elif isinstance(data, collections.Iterator):
# --> 389             raise TypeError("data argument can't be an iterator")
#     390         else:
#     391             try:
#
# TypeError: data argument can't be an iterator

# %%
from datetime import datetime

'''
# slower, time=0.00527501106262
for (i, entry) in enumerate(data['features']):
    place = entry['properties']['place']
#     cause = entry['properties']['type']
    if ('California' in place) or ('CA' in place):
#     if (('California' in place) or ('CA' in place)) and (cause == 'earthquake'):
        record = {}
        record['place'] = place
        record['time'] = entry['properties']['time']
        record['magnitude'] = entry['properties']['mag']
        cali.append(record)
        # check types above (do we still have to if we use lambda?)
'''
    
in_california = lambda x: ('California' in x['properties']['place']) or \
                          ('CA' in x['properties']['place'])
select_fields = lambda x: {'time': x['properties']['time'], 
                           'place': x['properties']['place'], 
                           'magnitude': x['properties']['mag']}

cali = filter(in_california, data['features'])
cali = map(select_fields, cali)
# faster, time = 0.00476717948914
        
print len(cali)
# print cali[0] # {'magnitude': 1.75, 'place': '5km NW of The Geysers, CA', 'time': 1524287209810}

format_time = lambda x: datetime.utcfromtimestamp(int(x) / 1000.0).strftime('%Y-%m-%dT%H:%M:%S') + '+00:00'
format_place = lambda x: str(x)
format_mag = lambda x: 'Magnitude: {}'.format(x) # better to use str.format as it converts its arguments into strings
format_output = lambda x: '{} | {} | {}'.format(format_time(x['time']), 
                                                format_place(x['place']), 
                                                format_mag(x['magnitude']))

cali_sorted = sorted(cali, key=lambda x: (x['magnitude'], x['time']))

results = map(format_output, cali_sorted)

for result in results:
    print result
    
# time 0.389930963516, faster

# output format: 2017-07-13T22:32:48+00:00 | 15km SE of Mammoth Lakes, California | Magnitude: 0.92
# time conversion function
# check data type?
# Out:
# --------------------------------------------------------------------------
# NameError                                Traceback (most recent call last)
# <ipython-input-2-89c6db30bd2d> in <module>()
#      21                            'magnitude': x['properties']['mag']}
#      22
# ---> 23 cali = filter(in_california, data['features'])
#      24 cali = map(select_fields, cali)
#      25 # faster, time = 0.00476717948914
#
# NameError: name 'data' is not defined

# %%
import pandas as pd
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot, plot
from plotly.graph_objs import *

init_notebook_mode(connected=True)
mapbox_access_token = 'pk.eyJ1IjoieW91Z29lcmljIiwiYSI6ImNqZ2R4cmpsbTI3dzcycXFzdHRrdnFobGUifQ.xwe3ccbSH-QrCY9WPoYJ2w'

df = pd.io.json.json_normalize(data['features'])
df = df[['properties.time', 'properties.place', 'properties.mag', 'geometry.coordinates']] # keep columns relevant to output
df_cali = df[df['properties.place'].str.contains('California|CA')] # find entries with 'place' value containing 'California' or 'CA', 628 records
df_cali = df_cali.rename(index=str, columns={'properties.time': 'time', 'properties.place': 'place', 'properties.mag': 'mag'})
df_cali['long'] = df_cali['geometry.coordinates'].apply(lambda x: x[0])
df_cali['lat'] = df_cali['geometry.coordinates'].apply(lambda x: x[1])
df_cali = df_cali.drop(['geometry.coordinates'], axis=1)

site_lat = df_cali.lat
site_lon = df_cali.long
locations_name = df_cali.place

format_time = lambda x: datetime.utcfromtimestamp(int(x) / 1000.0).strftime('%Y-%m-%dT%H:%M:%S') + '+00:00'

df_cali_sorted = df_cali.sort_values(['mag', 'time'], ascending=True) # sort by magnitude, then time occurred
print df_cali_sorted.head()

scl = [ [0, "rgb(255, 160, 30)"], [1, "rgb(200, 0, 0)"] ]

data_cali = Data([
            Scattermapbox(
                lat = site_lat,
                lon = site_lon,
                mode = 'markers',
                marker = Marker(
                        size = 14,
                        color = df_cali['mag'],
                        colorscale = scl,
                        cmin = df_cali['mag'].min(),
                        cmax = df_cali['mag'].max(),
                        opacity = 0.8,
                        colorbar=dict(
                            title="Magnitude"
                            )
                        ),
                ),
            Scattermapbox(
                lat = site_lat,
                lon = site_lon,
                mode = 'markers',
                marker = Marker(
                    size = 6,
                    color = 'rgb(240, 200, 170)',
                    opacity = 0.5
                ),
            )]
        )
        
layout = Layout(
        title = 'Earthquake in California from Past Month',
        autosize = True,
        hovermode = 'closest',
        showlegend = False,
        mapbox = dict(
                accesstoken = mapbox_access_token,
                bearing = 0,
                center = dict(
                        lat=38,
                        lon=-98
                ),
        pitch = 0,
        zoom = 3,
        style = 'outdoors'
        ),
    )

fig = dict(data=data_cali, layout=layout)
iplot(fig, filename='Earthquake in California from Past Month')
plot(fig, filename='caliDataPlotly.html')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
#                time                               place   mag        long  \
# 9133  1522217374350                 6km WNW of Cobb, CA -0.41 -122.792667
# 8698  1522327419335        3km E of Truckee, California -0.30 -120.141000
# 8188  1522455888154      4km NNE of Truckee, California -0.30 -120.162800
# 2048  1524030592481  2km WSW of Tahoe Vista, California -0.30 -120.081200
# 2915  1523780879710                 8km WSW of Anza, CA -0.28 -116.747667
#
#             lat
# 9133  38.835000
# 8698  39.325600
# 8188  39.364000
# 2048  39.234200
# 2915  33.518833
# <div id="cdcc9f4a-c8ad-434d-ad3c-bda1094bb39f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("cdcc9f4a-c8ad-434d-ad3c-bda1094bb39f", [{"marker": {"opacity": 0.8, "cmin": -0.41, "colorscale": [[0, "rgb(255, 160, 30)"], [1, "rgb(200, 0, 0)"]], "color": [1.78, 2.38, 0.37, 0.72, 2.3, 1.29, 1.7, 2.39, 0.61, 0.9, 0.5, 1.11, 0.13, 2.51, 0.56, 0.98, 1.62, 0.86, 0.65, 0.45, 1.37, 0.26, 1.0, 2.36, 1.83, 0.56, 1.19, 1.89, 1.76, 0.89, 0.88, 2.87, 0.82, 0.89, 1.88, 0.76, 2.22, 0.48, 1.58, 2.19, 0.54, 0.61, 1.99, 0.95, 1.4, 0.78, 0.49, 1.29, 0.94, 0.87, 1.67, 1.19, 0.77, 0.56, 0.88, 0.64, 0.87, 1.31, 1.33, 2.45, 1.03, 2.68, 2.07, 0.54, 1.0, 1.02, 1.13, 1.11, 1.64, 1.85, 0.97, 1.55, 1.42, 0.5, 1.28, 1.37, 1.17, 1.49, 0.6, 0.87, 1.69, 0.52, 0.8, 0.91, 1.81, 0.51, 0.95, 0.83, 1.75, 2.29, 0.79, 0.28, 0.4, 0.91, 0.4, 0.7, 0.89, 0.31, 1.1, 1.1, 2.33, 1.69, 1.94, 0.62, 0.97, 1.07, 0.61, 1.2, 0.86, 1.16, 0.59, 1.74, 0.83, 0.61, 0.37, 0.36, 0.72, 0.88, 1.37, -0.1, 0.44, 0.58, 0.75, 0.2, 0.9, 0.68, 0.93, 0.39, 1.21, 0.73, 0.62, 1.1, 1.0, 0.56, 2.22, 1.0, 1.64, 0.4, 0.75, 1.0, 0.2, 0.75, 0.49, 0.8, 0.24, 0.79, 1.55, 1.0, 1.1, 1.98, 0.3, 0.4, 1.05, 1.2, 0.57, 1.43, 1.1, 0.87, 1.31, 1.95, 0.87, 0.56, 1.16, 0.78, 2.3, 0.94, 1.29, 0.55, 0.68, 0.93, 1.07, 1.62, 0.83, 2.33, 0.78, 0.95, 0.33, 1.61, 1.23, 1.82, 0.0, 0.59, 1.68, 1.89, 1.38, 1.18, 1.34, 1.56, 1.16, 0.57, 0.5, 1.44, 1.11, 0.26, 0.89, 0.95, 0.49, 1.93, 1.65, 0.69, 0.81, 1.6, 0.47, 0.85, 0.25, 1.7, 0.34, 0.83, 0.29, 0.42, 0.34, 0.44, 0.84, 0.63, -0.21, 0.66, 0.62, 0.26, 0.3, 1.17, 0.77, 1.19, 0.28, 0.4, 0.69, 0.33, 0.19, 0.53, 0.46, 1.25, 0.83, 1.29, 1.17, 1.91, 2.13, 1.29, 0.57, 1.49, 0.46, 0.85, 1.14, 2.1, 0.95, 0.1, 0.9, 0.35, 2.29, 1.05, 1.47, 0.83, -0.11, 1.13, 0.87, 1.23, 0.56, 0.56, 0.91, 0.8, 1.1, 1.35, 0.33, 2.14, 1.1, 0.66, 2.43, 1.22, 0.72, 0.15, 0.97, 0.86, 2.18, 0.93, 2.19, 0.38, 1.63, 0.6, 0.74, 0.38, 0.8, 1.1, 0.77, 0.89, 1.04, 0.56, 0.56, 0.43, 3.87, 0.99, 0.73, 2.07, 1.13, 1.88, 1.16, 1.3, 0.4, 0.33, 0.59, 2.9, 0.85, 0.75, 0.94, 0.39, 1.06, 0.36, 0.75, 1.24, 0.66, 0.86, 1.64, 0.71, 0.3, 0.36, 2.43, 1.77, 1.15, 0.83, 0.42, 0.38, 1.06, 0.49, 0.41, 0.64, 1.0, 0.36, 0.41, 0.4, 0.39, 0.65, 0.27, 0.34, 2.57, 0.83, 0.61, 1.51, 0.47, 0.36, 0.69, 0.02, 1.05, 0.41, 0.61, 0.28, 0.83, 0.12, 0.25, 1.5, 1.52, 1.51, 0.5, 1.79, 0.57, 0.91, 0.33, 1.78, 0.88, 0.59, 0.27, 0.26, 0.23, 0.8, 2.05, 0.34, 1.07, 0.01, 1.05, 0.47, 1.51, 0.64, 0.4, 1.66, 0.46, 0.26, 1.68, 1.09, 0.59, 1.07, 1.01, 1.13, 0.63, 0.03, 0.4, 1.52, 0.95, 1.45, 1.05, 1.64, 1.07, 0.28, 0.89, 0.34, 0.42, 0.96, 0.28, 1.07, 1.97, 0.68, 0.27, 0.39, 0.42, 0.39, 0.76, 1.01, 0.48, 0.84, 1.18, 0.02, 0.02, 0.37, -0.07, 0.36, 0.37, 3.6, 0.86, 0.83, 1.06, 0.41, 0.5, 0.74, 0.32, 1.96, 1.05, 1.37, 1.1, 0.78, 0.2, 1.31, 1.72, 1.29, 1.81, 0.44, 0.87, 0.63, 2.73, 1.24, 0.22, 0.06, -0.08, 1.04, 0.44, 0.55, 0.92, 0.9, 1.39, 0.88, 1.25, 1.04, 0.85, 0.11, 1.27, 0.85, 0.56, -0.2, 0.58, 0.97, 1.67, 1.6, 1.6, 1.7, 0.96, 3.11, 1.2, -0.2, 1.82, -0.1, 0.77, 1.56, 0.8, 2.26, 1.83, 0.88, 0.59, 0.89, 0.72, 2.0, 0.55, 1.04, 1.25, 0.63, 1.73, 1.8, 0.24, 1.06, 1.63, 0.91, 0.55, 0.89, 1.6, 0.88, 0.56, 0.24, 0.96, 0.89, 0.55, 0.44, 0.56, 1.01, 0.55, 0.77, 2.71, 1.58, 0.82, 0.69, 0.41, 0.38, -0.21, 0.19, 0.32, 0.56, 0.98, 0.69, 0.24, 0.52, 0.46, 0.72, 0.92, 1.07, 0.76, 0.79, 2.46, 0.0, 1.15, 1.91, 0.67, 1.32, 0.81, 1.21, 1.77, 0.87, 0.53, 0.51, 0.56, 1.04, 0.05, 1.9, 0.81, 1.34, 1.24, 0.88, 0.92, 1.24, 0.26, 1.47, 0.5, 1.43, 0.99, 0.82, 2.27, 0.7, 0.61, 1.41, 0.47, 1.04, 0.27, 0.49, 1.87, 1.35, 0.7, 0.74, 0.76, 0.98, 0.66, 1.2, 0.54, 0.89, 1.35, 0.81, 0.3, 0.14, 0.04, 0.29, 0.69, 0.66, 0.4, 1.34, 0.83, 1.89, 0.47, 0.57, 1.29, 1.88, 0.33, 0.94, 0.83, 0.6, 0.56, 1.75, 1.17, 0.87, 0.65, 0.71, 0.94, 1.12, 1.35, 1.57, 1.78, 2.48, 2.91, 1.61, 1.14, 1.41, 0.66, 1.75, 0.68, 1.75, 0.58, 0.4 ...
# 'file:///Users/eric/Desktop/appl/caliDataPlotly.html'

# %%
in_california = lambda x: ('California' in x['properties']['place']) or \
                          ('CA' in x['properties']['place'])

cali = filter(in_california, data['features'])

for entry in cali:
    del entry['properties']['rms']
    del entry['properties']['code']
    del entry['properties']['cdi']
    del entry['properties']['sources']
    del entry['properties']['nst']
    del entry['properties']['tz']
    del entry['properties']['title']
    del entry['properties']['magType']
    del entry['properties']['detail']
    del entry['properties']['sig']
    del entry['properties']['net']
    del entry['properties']['status']
    del entry['properties']['updated']
    del entry['properties']['felt']
    del entry['properties']['alert']
    del entry['properties']['dmin']
    del entry['properties']['gap']
    del entry['properties']['types']
    del entry['properties']['url']
    del entry['properties']['ids']
    del entry['properties']['tsunami']
    del entry['properties']['mmi']

with open('cali.json', 'w') as f:
    json.dump(cali, f)

# faster, time = 0.00476717948914
        
print len(cali)
print cali[0]
# Out:
# 3221
# {u'geometry': {u'type': u'Point', u'coordinates': [-122.0886688, 39.4000015, 4.52]}, u'type': u'Feature', u'properties': {u'type': u'earthquake', u'mag': 1.78, u'place': u'16km NNE of Maxwell, CA', u'time': 1524667182790}, u'id': u'nc73005951'}
